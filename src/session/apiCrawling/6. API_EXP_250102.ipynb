# %%
# 라이브러리 설치 
# 최초 1회만 실행(이젠 아시죠?)
# pip install requests

## 라이브러리 임포트
import requests
import pprint
import json
import pandas as pd

# %%
# 서울시 열린광장에서 복사해온 KEY 값과 URL 을 기입합니다.
# --------------------------------------------------------------->xml 에서 json 으로 변경<---------------
# -------------------------------------------------------------------->여기<-----------------------------
url = 'http://openapi.seoul.go.kr:8088/736567756761726439365543736d77/json/ServiceInternetShopInfo/1/100/'

# request library 를 이용한 json file 로드 
response = requests.get(url).json()

# %%
# json 데이터 확인 
response
# Out:
# {'ServiceInternetShopInfo': {'list_total_count': 155592,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'COMPANY': '(주) 지니뮤직',
#     'SHOP_NAME': '지니뮤직 / Genie Music',
#     'DOMAIN_NAME': 'www.genie.co.kr',
#     'TEL': '1577-5337',
#     'EMAIL': 'geniemusic@kt.com',
#     'UPJONG_NBR': '',
#     'YPFORM': ' 콘텐츠.서비스',
#     'FIRST_HEO_DATE': '2007-10-15',
#     'COM_ADDR': '서울특별시 강남구 강남대로 456, 4-9층 한석타워 (역삼동)',
#     'STAT_NM': '영업중',
#     'TOT_RATINGPOINT': '3',
#     'CHOGI_RATINGPOINT': '3',
#     'CHUNG_RATINGPOINT': '3',
#     'DEAL_RATINGPOINT': '3',
#     'PYOJUN_RATINGPOINT': '3',
#     'SECURITY_RATINGPOINT': '3',
#     'SERVICE': ' 인터넷게임',
#     'CHUNG': '소비자분쟁해결기준 제시',
#     'CHOGI': ' 상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호 호스팅 사업자',
#     'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 상품권 휴대폰 기타',
#     'PYOJUN': '표준약관 사용',
#     'P_INFO_CARE': '초기화면표시',
#     'PER_INFO': '',
#     'DEAL_CARE': '해당사항없음',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '해당사항 없음',
#     'BAESONG': '해당 없음',
#     'CLIENT_BBS': '있다(공개)',
#     'LEAVE': '회원탈퇴 가능',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-23'},
#    {'COMPANY': '디에디트원',
#     'SHOP_NAME': '디에디트원',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_RVXL895X7L',
#     'TEL': '010-2102-3486',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-04582',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-12',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '카페유알피 영등포점',
#     'SHOP_NAME': '카페유알피 영등포점',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_7siiyEAL1A',
#     'TEL': '010-9458-1705',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울영등포-2421',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-30',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '강변상회',
#     'SHOP_NAME': '강변상회',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_GXqkC78K1r',
#     'TEL': '010-8628-1610',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동작-1082',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-02',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '다담',
#     'SHOP_NAME': '다담',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_uHAAeSL2no',
#     'TEL': '010-8580-8467',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서초-3162',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-12',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '셀앤쉐어(sell&share)',
#     'SHOP_NAME': '셀앤쉐어(sell&share)',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_jurgQvxXf6',
#     'TEL': '010-5880-2300',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울양천-1038',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '아쥬어 클래식',
#     'SHOP_NAME': '아쥬어 클래식',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_stF5YFWzt8',
#     'TEL': '010-7637-6367',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-2684',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-01',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '와이투엠 리테일1',
#     'SHOP_NAME': '와이투엠 리테일1',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_Di1ZvKE5ho',
#     'TEL': '010-3319-9054',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울중랑-1369',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '민투어트래블',
#     'SHOP_NAME': '민투어트래블',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_vEfrJoDi9y',
#     'TEL': '010-2727-5684',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울영등포-2568',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-24',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '아일린의마켓',
#     'SHOP_NAME': '아일린의마켓',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_EPBRrpbLb9',
#     'TEL': '010-8928-3355',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울관악-1750',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '패닉 크리에이티브 스튜디오',
#     'SHOP_NAME': '패닉 크리에이티브 스튜디오',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_EnVg3Gwabm',
#     'TEL': '010-3728-4458',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울용산-1267',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-27',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '유니버스컴퍼니',
#     'SHOP_NAME': '유니버스컴퍼니',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_1Drbfter2b',
#     'TEL': '010-6821-7622',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-04321',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-01',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '한국joybond',
#     'SHOP_NAME': '한국joybond',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_aatJmvM16U',
#     'TEL': '010-9132-5081',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울중랑-1227',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-11',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '나비효과',
#     'SHOP_NAME': '나비효과',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_8DfoRhkaqC',
#     'TEL': '010-8386-5023',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-04606',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-15',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '핀젤',
#     'SHOP_NAME': '핀젤',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_7SjAVSMCr6',
#     'TEL': '010-2728-8920',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서대문-0975',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-22',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '유스창고',
#     'SHOP_NAME': '유스창고',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_WxfiQaiVXs',
#     'TEL': '010-3500-4770',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동대문-1382',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-12',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '히로시카프하루',
#     'SHOP_NAME': '히로시카프하루',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_mZbmSWStKY',
#     'TEL': '010-7905-1708',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강서-2764',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-30',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '에스전기',
#     'SHOP_NAME': '에스전기',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_6fZ8dGWzo8',
#     'TEL': '010-3910-8876',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서초-2690',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-09',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '드리프트뮤즈',
#     'SHOP_NAME': '드리프트뮤즈',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_QUwdEVJH33',
#     'TEL': '010-9703-6061',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울종로-1149',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-31',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '다이아 씨엔씨',
#     'SHOP_NAME': '다이아 씨엔씨',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_kPLG2cvSdV',
#     'TEL': '010-9660-5692',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울양천-1215',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '해사드 살롱',
#     'SHOP_NAME': '해사드 살롱',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_Ue6hL648aW',
#     'TEL': '010-3511-2914',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강서-2463',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-31',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '블러쉬 코리아',
#     'SHOP_NAME': '블러쉬 코리아',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_gzuCFZuvpN',
#     'TEL': '010-5917-9952',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울노원-1394',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-10-14',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '유엔케이6',
#     'SHOP_NAME': '유엔케이6',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_sQm3JvYF1u',
#     'TEL': '010-2669-7634',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강서-2089',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-01',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '메가후르츠 방이점',
#     'SHOP_NAME': '메가후르츠 방이점',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_ZRxuhg58PG',
#     'TEL': '010-7234-9036',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-2482',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-17',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '씨에이치컴퍼니',
#     'SHOP_NAME': '씨에이치컴퍼니',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_qsbT24djgb',
#     'TEL': '010-5505-7781',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울노원-1223',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-21',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '조용한악동',
#     'SHOP_NAME': '조용한악동',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_MDEZ5CgZrw',
#     'TEL': '010-5644-9993',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강동-1662',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-10',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': 'GKUER',
#     'SHOP_NAME': 'GKUER',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_oszjCcARBR',
#     'TEL': '010-5795-3278',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-3124',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-19',
#     'COM_ADDR': '서울특별시 송파구 올림픽로 135 (잠실동, 리센츠) 256동 1901호',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '스푼',
#     'SHOP_NAME': '스푼',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_ynPPJzehaG',
#     'TEL': '010-4221-2711',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울용산-1034',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-30',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '다복한두유네',
#     'SHOP_NAME': '다복한두유네',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_77aNmvK4hx',
#     'TEL': '010-2131-3632',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강서-2400',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-25',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '김푸딩동',
#     'SHOP_NAME': '김푸딩동',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_T8nKzBH2bL',
#     'TEL': '010-5409-6807',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-04811',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-24',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '루비카트',
#     'SHOP_NAME': '루비카트',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_DLjXYnajH2',
#     'TEL': '010-2655-5815',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서초-3471',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-10',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '온기오',
#     'SHOP_NAME': '온기오',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_XUVDCdPjF2',
#     'TEL': '010-5495-3204',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울은평-1079',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-29',
#     'COM_ADDR': '경기도 파주시 월롱면 휴암로 177-11 402-E013호',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '피치핑크',
#     'SHOP_NAME': '피치핑크',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_jMMit6qHVe',
#     'TEL': '010-3217-5144',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동작-0940',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-25',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '윤태웅',
#     'SHOP_NAME': '윤태웅',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_Wn2jtYWthm',
#     'TEL': '010-5419-1939',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동작-1126',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-10',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '깅',
#     'SHOP_NAME': '깅',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_HegtwbjyR6',
#     'TEL': '010-7654-5019',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서초-2889',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-24',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '루컴퍼니',
#     'SHOP_NAME': '루컴퍼니',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_5S7UdK8XLB',
#     'TEL': '010-3239-9699',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울성북-0986',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-12',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '아서스',
#     'SHOP_NAME': '아서스',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_FtKMsd6h39',
#     'TEL': '010-9112-1716',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-2671',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-31',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '오늘도기쁨38',
#     'SHOP_NAME': '오늘도기쁨38',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_TTWSNuUZtx',
#     'TEL': '010-3044-0106',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-1391',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '슈퍼픽스',
#     'SHOP_NAME': '슈퍼픽스',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_MAheiMKJB3',
#     'TEL': '010-5303-7589',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-04873',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '오키나와파인',
#     'SHOP_NAME': '오키나와파인',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_mbrELa6xGg',
#     'TEL': '010-8235-1708',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동대문-1779',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '최씨네잡화점',
#     'SHOP_NAME': '최씨네잡화점',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_VnLgwTC7Sq',
#     'TEL': '010-2020-5372',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울광진-1241',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-08',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '모엘유통직구',
#     'SHOP_NAME': '모엘유통직구',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_GAbkn9DgPB',
#     'TEL': '010-6577-5690',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동대문-1493',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-30',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '스튜디오랑고',
#     'SHOP_NAME': '스튜디오랑고',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_E6qSotkz7K',
#     'TEL': '010-7707-7840',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울노원-1352',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-27',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '창작 더하기',
#     'SHOP_NAME': '창작 더하기',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_7Fks7nsT9A',
#     'TEL': '010-8611-9192',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강서-2932',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-20',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '순무마켓',
#     'SHOP_NAME': '순무마켓',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_UwHEkgPAon',
#     'TEL': '010-5874-2256',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울도봉-0622',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-08',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '름',
#     'SHOP_NAME': '름',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_drwJQTqi1o',
#     'TEL': '010-3316-7307',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서대문-1104',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-23',
#     'COM_ADDR': '서울특별시 서대문구 신촌로 25 (창천동) 2층 3812호',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '나비몰',
#     'SHOP_NAME': '나비몰',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_4dd6ndHGLW',
#     'TEL': '010-3298-8144',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울관악-1245',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-01',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '아바링크(AVA_Link)',
#     'SHOP_NAME': '아바링크(AVA_Link)',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_7rY6uSVGHZ',
#     'TEL': '010-4699-5576',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-2682',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-31',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '메이크머니스튜디오',
#     'SHOP_NAME': '메이크머니스튜디오',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_wq1cYBerNm',
#     'TEL': '010-7143-7566',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서초-3468',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-09',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '제이엠서비스',
#     'SHOP_NAME': '제이엠서비스',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_VQzqGBKvhh',
#     'TEL': '010-9181-1198',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-05398',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '심(SIM)',
#     'SHOP_NAME': '심(SIM)',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_P9pWzQBTxX',
#     'TEL': '010-3866-6565',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동작-0946',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '성원하이닉스',
#     'SHOP_NAME': '성원하이닉스',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_rDvzEGpTuA',
#     'TEL': '010-8591-5569',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울마포-2373',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '라이프집(life.zip)',
#     'SHOP_NAME': '라이프집(life.zip)',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_R7eJAMmHHD',
#     'TEL': '010-5036-2606',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울양천-1208',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-24',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '알루리',
#     'SHOP_NAME': '알루리',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_RS9zMn9TJ7',
#     'TEL': '010-8872-6674',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울노원-1353',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-29',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '피크포인트',
#     'SHOP_NAME': '피크포인트',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_Co3pdpdJPk',
#     'TEL': '010-8189-3122',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-2842',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-19',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '안가네농장',
#     'SHOP_NAME': '안가네농장',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_cYypAQrbmU',
#     'TEL': '010-4559-3359',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울종로-1125',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '나나',
#     'SHOP_NAME': '나나',
#     'DOMAIN_NAME': 'buy.tosspaytments.com/shops/mob_fn16gjRR86',
#     'TEL': '010-2770-7570',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울성동-0728',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-04-09',
#     'COM_ADDR': '서울특별시 성동구 둘레길 45 (성수동1가) 3층 302호',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '4퍼센트',
#     'SHOP_NAME': '4퍼센트',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_6NQNUd9RhF',
#     'TEL': '010-5852-4601',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울광진-1549',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-09',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '블랙앤화이트',
#     'SHOP_NAME': '블랙앤화이트',
# ...
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '봄날',
#     'SHOP_NAME': '봄날',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_mmNb1PA6v7',
#     'TEL': '010-5557-9175',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울용산-1230',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-19',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '라라샵',
#     'SHOP_NAME': '라라샵',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_HyXfQMSFhP',
#     'TEL': '010-3646-7097',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강동-1509',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-07',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '진주아이',
#     'SHOP_NAME': '진주아이',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_22raqgxWK1',
#     'TEL': '010-9075-0063',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울서대문-1049',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-08',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '통곡물과바른먹거리 ',
#     'SHOP_NAME': '통곡물과바른먹거리 ',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_JbWVMgVidT',
#     'TEL': '010-3142-1361',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울동작-1167',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-26',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '아팜',
#     'SHOP_NAME': '아팜',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_EuSHvvKhdU',
#     'TEL': '010-9203-3754',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울중랑-1225',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-11',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '정감',
#     'SHOP_NAME': '정감',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_ZSDGuNCX6a',
#     'TEL': '010-4408-4443',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울성북-1048',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-29',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '스마트머니',
#     'SHOP_NAME': '스마트머니',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_sx2LMk26yW',
#     'TEL': '010-2487-3004',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울중랑-1531',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-11',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '체리',
#     'SHOP_NAME': '체리',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_fCuB2sZ3Ut',
#     'TEL': '010-8726-7809',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강동-1564',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-19',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '스타리스트 STARLIST',
#     'SHOP_NAME': '스타리스트 STARLIST',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_vsAAp2yJUT',
#     'TEL': '010-3252-1331',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울마포-2937',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '오느아',
#     'SHOP_NAME': '오느아',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_rTV44boQPf',
#     'TEL': '010-4036-4110',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울성동-1525',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': 'dapeartdirector',
#     'SHOP_NAME': 'dapeartdirector',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_ngNNro5D9n',
#     'TEL': '010-9346-4421',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울광진-1375',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-01',
#     'COM_ADDR': '서울특별시 용산구 녹사평대로46길 34-7(이태원동) 2층',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '어웨이크여미',
#     'SHOP_NAME': '어웨이크여미',
#     'DOMAIN_NAME': '자사몰(buy.tosspayments.com/shops/mob_mcCKPcBLwA',
#     'TEL': '010-4489-7256',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울송파-2710',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-02',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '동해몰',
#     'SHOP_NAME': '동해몰',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_M5Q8umKscv',
#     'TEL': '010-2998-6888',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울구로-1556',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-09-03',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '진토',
#     'SHOP_NAME': '진토',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_F5FUH1UzxH',
#     'TEL': '010-4847-5117',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울마포-2617',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-29',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '일조시스템',
#     'SHOP_NAME': '일조시스템',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_FzmS7965Bd',
#     'TEL': '010-9929-6560',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울노원-1157',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '제이솔루션',
#     'SHOP_NAME': '제이솔루션',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_GxNvoW2T5o',
#     'TEL': '010-4840-5005',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울관악-1486',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '비벡터',
#     'SHOP_NAME': '비벡터',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_2jFG2B6xZr',
#     'TEL': '010-5585-0896',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-04597',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-12',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '요나스',
#     'SHOP_NAME': '요나스',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_1EDWZS4WvY',
#     'TEL': '010-4238-6454',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울마포-2371',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-07-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'},
#    {'COMPANY': '지킴약국',
#     'SHOP_NAME': '지킴약국',
#     'DOMAIN_NAME': 'buy.tosspayments.com/shops/mob_qyUtgpdw1t',
#     'TEL': '010-7443-0529',
#     'EMAIL': 'khyoon57@korea.com',
#     'UPJONG_NBR': '2024-서울강남-05044',
#     'YPFORM': '',
#     'FIRST_HEO_DATE': '2024-08-05',
#     'COM_ADDR': '확인안됨',
#     'STAT_NM': '휴업중',
#     'TOT_RATINGPOINT': '',
#     'CHOGI_RATINGPOINT': '',
#     'CHUNG_RATINGPOINT': '',
#     'DEAL_RATINGPOINT': '',
#     'PYOJUN_RATINGPOINT': '',
#     'SECURITY_RATINGPOINT': '',
#     'SERVICE': '',
#     'CHUNG': '',
#     'CHOGI': '',
#     'GYULJE': '',
#     'PYOJUN': '',
#     'P_INFO_CARE': '',
#     'PER_INFO': '',
#     'DEAL_CARE': '',
#     'SSL_YN': '',
#     'INJEUNG': '',
#     'BAESONG_YEJEONG': '',
#     'BAESONG': '',
#     'CLIENT_BBS': '',
#     'LEAVE': '',
#     'KAESOL_YEAR': '',
#     'REG_DATE': '2024-12-16'}]}}

# %%
# json file 의 key 값 확인 (각 딕셔너리 값으로 이뤄져있음)
response['ServiceInternetShopInfo'].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
# json 파일의 row 데이터 로드 
response['ServiceInternetShopInfo']['row']
# Out:
# [{'COMPANY': '주식회사 에자일몽키테니스',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'http://www.rocktennis.kr',
#   'TEL': '02-2135-2791',
#   'EMAIL': 'parking456@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-07',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '코즈믹크루',
#   'SHOP_NAME': '코즈믹크루 / cosmic crew',
#   'DOMAIN_NAME': 'https://instashop.srookpay.com/cosmiccrew',
#   'TEL': '010-5588-2560',
#   'EMAIL': 'cosmiccrewbusiness@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-11',
#   'COM_ADDR': '서울특별시 강남구 선릉로112길 21-4, 202호',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '꿈틀',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_Zz5oaRpcvp',
#   'TEL': '확인안됨',
#   'EMAIL': 'impressives2@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-08',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '리지필라테스',
#   'SHOP_NAME': '리지필라테스 (네이버 예약 입점)',
#   'DOMAIN_NAME': 'https://booking.naver.com/booking/13/bizes/747049',
#   'TEL': '010-8074-8811',
#   'EMAIL': 'bomsoft@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 오픈마켓',
#   'FIRST_HEO_DATE': '2023-10-27',
#   'COM_ADDR': '서울특별시 서초구 서래로 39, 5층',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '1',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '1',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': '',
#   'CHUNG': '가능하나 일부품목제외, 기간축소',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 사업자등록번호 사이버몰이용약관 호스팅 사업자',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰 기타',
#   'PYOJUN': '자체약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '해당사항없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '해당사항 없음',
#   'BAESONG': '해당 없음',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '호작',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/',
#   'TEL': '확인안됨',
#   'EMAIL': 'lugere22@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-06-27',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '시안홀딩스',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_7mDFpiTmCU',
#   'TEL': '확인안됨',
#   'EMAIL': 'ajh117@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-09',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '대기업',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops',
#   'TEL': '확인안됨',
#   'EMAIL': 'daein304@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '주식회사 브라보헬스',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'www.bravoinhealth.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'ceo@bravoinhealth.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '살랑살랑',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_4ftjsAQ2Vw',
#   'TEL': '확인안됨',
#   'EMAIL': 'serini002@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '사적인 공간 해서',
#   'SHOP_NAME': '쏘댓 스튜디오 / sothat_studio(네이버 스마트스토어 입점)',
#   'DOMAIN_NAME': 'https://smartstore.naver.com/sothat_studio',
#   'TEL': '010-8802-9389',
#   'EMAIL': 'ksreum@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 오픈마켓',
#   'FIRST_HEO_DATE': '2023-12-13',
#   'COM_ADDR': '서울특별시 구로구 경인로35길 16-4 4층',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '3',
#   'CHOGI_RATINGPOINT': '3',
#   'CHUNG_RATINGPOINT': '3',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 가구/생활/주방',
#   'CHUNG': '가능',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호 호스팅 사업자',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 상품권 기타',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '에스크로제도',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '있다',
#   'BAESONG': '소비자(왕복택배비 부담)',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '수련',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_3FMsQZXZYa',
#   'TEL': '확인안됨',
#   'EMAIL': 'ainyoga0@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '주식회사 에이슬립',
#   'SHOP_NAME': '슬립코치 / sleepcoach',
#   'DOMAIN_NAME': 'https://sleepcoach.kr/',
#   'TEL': '02-567-2408',
#   'EMAIL': 'sleepcoach_cs@asleep.ai',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 콘텐츠.서비스',
#   'FIRST_HEO_DATE': '2023-09-14',
#   'COM_ADDR': '서울특별시 강남구 테헤란로415 6층',
#   'STAT_NM': '등록정보불일치',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '3',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '1',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 의료서비스',
#   'CHUNG': '철회대상 품목 취급하지 않음',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 기타',
#   'PYOJUN': '자체약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '해당사항없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '해당사항 없음',
#   'BAESONG': '해당 없음',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '주식회사 펄리글로우',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'www.tosspayments.com/escrow',
#   'TEL': '확인안됨',
#   'EMAIL': 'pearlyglow.customer@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '포스트 필라테스',
#   'SHOP_NAME': '포스트 필라테스 한티점 / post pilates hanti',
#   'DOMAIN_NAME': 'https://postpilateshanti.modoo.at/',
#   'TEL': '02-558-7988/0507-1496-7988',
#   'EMAIL': 'postk0923@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-13',
#   'COM_ADDR': '서울특별시 강남구 선릉로 312(대치동 936)',
#   'STAT_NM': '광고용(홍보용)',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '용용스토어',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_h28ZLNwyBi',
#   'TEL': '확인안됨',
#   'EMAIL': 'yongyongstore@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-16',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '우미이노베이션(주)',
#   'SHOP_NAME': '우미이노베이션 / woomi innovation',
#   'DOMAIN_NAME': 'www.woomiinnovation.com',
#   'TEL': '02-3443-0004',
#   'EMAIL': 'jshu0811@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-13',
#   'COM_ADDR': '서울특별시 강남구 논현로 136길 6 삼대양빌딩 2층',
#   'STAT_NM': '광고용(홍보용)',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '눈치코치(Nunchi Kochi)',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/',
#   'TEL': '확인안됨',
#   'EMAIL': 'nunchikochi1@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-02-19',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '주식회사 빅마운틴엔터테인먼트',
#   'SHOP_NAME': '퀸즈아이 / QueenzEye',
#   'DOMAIN_NAME': 'https://queenzeye.bstage.in',
#   'TEL': '02-3443-6945',
#   'EMAIL': 'fan.queenzeye@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-12',
#   'COM_ADDR': '서울특별시 강남구 언주로97길 26, 지하1층 비01호',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '구대1등장사장19',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_CEN8A2HKzj',
#   'TEL': '확인안됨',
#   'EMAIL': 'no1.ceo.jang1@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '주식회사 로열마일',
#   'SHOP_NAME': '로열마일 / royalmile',
#   'DOMAIN_NAME': 'royalmile.co.kr',
#   'TEL': '02-2135-7617',
#   'EMAIL': 'help@royalmile.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 콘텐츠.서비스',
#   'FIRST_HEO_DATE': '2023-08-17',
#   'COM_ADDR': '서울 마포구 양화로 147, 아일렉스 6층 112호',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '1',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '1',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 예매.예약서비스',
#   'CHUNG': '가능하나 일부품목제외, 기간축소',
#   'CHOGI': ' 상호 소재지 전화번호 전자우편주소 사업자등록번호 통신판매신고번호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드',
#   'PYOJUN': '자체약관 사용',
#   'P_INFO_CARE': '초기화면이외에 표시(초기화면 미표시, 이용약관에 표시)',
#   'PER_INFO': '',
#   'DEAL_CARE': '해당사항없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '해당사항 없음',
#   'BAESONG': '해당 없음',
#   'CLIENT_BBS': '있다(비공개)',
#   'LEAVE': '회원가입이 없다',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '오늘도기쁨17',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_aGeEsFfp5U',
#   'TEL': '확인안됨',
#   'EMAIL': 'soo-edu@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-15',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '스더컴퍼니',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://restpiece.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'restpiece24@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '소잉아츠 필드(Sewing arts filled)',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'sewingartsfilled@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-01-16',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '작은얼굴이야기',
#   'SHOP_NAME': '작은얼굴이야기',
#   'DOMAIN_NAME': 'storyofsmallface.modoo.at/',
#   'TEL': '02-333-8695',
#   'EMAIL': 'eksdh7859@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 청약유인',
#   'FIRST_HEO_DATE': '2023-09-05',
#   'COM_ADDR': '서울특별시 마포구 서교동 352-1 2층',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '1',
#   'CHUNG_RATINGPOINT': '1',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': ' 예매.예약서비스',
#   'CHUNG': '가능하나 일부품목제외, 기간축소',
#   'CHOGI': ' 상호 소재지 호스팅 사업자',
#   'GYULJE': ' 현금입금(무통장,계좌이체등)',
#   'PYOJUN': '약관 없음',
#   'P_INFO_CARE': '개인정보취급방침 없음',
#   'PER_INFO': '',
#   'DEAL_CARE': '해당사항없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '해당사항 없음',
#   'BAESONG': '해당 없음',
#   'CLIENT_BBS': '게시판 없음',
#   'LEAVE': '회원가입이 없다',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '일타교육',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_gLXD1yLZBF',
#   'TEL': '확인안됨',
#   'EMAIL': 'iltaedu.info@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-15',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '에스테틱공간',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://www.tosspayments.com/',
#   'TEL': '확인안됨',
#   'EMAIL': 'leeduljjae@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-06-17',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '유연바디랩',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_srLnH43XvB',
#   'TEL': '확인안됨',
#   'EMAIL': 'yuyeon_bodylab@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '유소트',
#   'SHOP_NAME': '유소트 / yusot',
#   'DOMAIN_NAME': 'yusot.kr',
#   'TEL': '070-8098-9683',
#   'EMAIL': 'yusotcompany@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 일반쇼핑몰',
#   'FIRST_HEO_DATE': '2023-10-23',
#   'COM_ADDR': '서울 노원구 섬밭로 232',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '3',
#   'DEAL_RATINGPOINT': '1',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 신발/가방/패션잡화/귀금속',
#   'CHUNG': '가능',
#   'CHOGI': ' 상호 대표자 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호 호스팅 사업자',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '구매안전서비스없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '있다',
#   'BAESONG': '소비자(반품택배비만 부담)',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '시구왕계',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_ggtQpw1n4k',
#   'TEL': '확인안됨',
#   'EMAIL': 's2nana24@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-05-22',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '키베이스 / Keybase',
#   'SHOP_NAME': '엠디공구 / md09',
#   'DOMAIN_NAME': 'https://md09.co.kr/',
#   'TEL': '02-519-8008/02-519-8020',
#   'EMAIL': 'contact@keybase.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-11-30',
#   'COM_ADDR': '서울특별시 강남구 논현로 416 6층 (역삼동, 운기빌딩)',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '초이애',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_Xnb6WVzijY',
#   'TEL': '확인안됨',
#   'EMAIL': 'k4281004@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-06-10',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-26'},
#  {'COMPANY': '주식회사 판다코리아닷컴 (PANDAKOREA DOTCOM)',
#   'SHOP_NAME': 'pamdakorea.com/판다코리아닷컴',
#   'DOMAIN_NAME': 'www.pandakorea.com',
#   'TEL': '070-4866-5831',
#   'EMAIL': 'contact@pandakorea.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2014-07-01',
#   'COM_ADDR': '서울특별시 성동구 상원1길 26 4층 (뚝섬역 5번출구)',
#   'STAT_NM': '광고용(홍보용)',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '더든',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_Be56nx6GBE',
#   'TEL': '확인안됨',
#   'EMAIL': 'sunkyung9682@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2022-09-27',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '간직',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_kxbK6h1345',
#   'TEL': '확인안됨',
#   'EMAIL': 'woninter815@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '썸원픽',
#   'SHOP_NAME': '썸원픽/someonepick',
#   'DOMAIN_NAME': 'someonepick.cafe24.com',
#   'TEL': '010-2844-2926',
#   'EMAIL': 'somedayluv7@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-03',
#   'COM_ADDR': '서울특별시 서초구 사평대로55길 28, 101호 (반포동)',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '엔터플러스(ENTER+)',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_z1Q8rT3VDj',
#   'TEL': '확인안됨',
#   'EMAIL': 'enterplus2022@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-05-22',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '에이투씨',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'www.thetog.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'theblow69@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-12-06',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '아르더글로벌',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_NXZTy9qxJi',
#   'TEL': '확인안됨',
#   'EMAIL': 'ardorglobal@ardorglobal.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-22',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '인셀덤 헬리오시티',
#   'SHOP_NAME': '인셀덤 헬리오시티 핑크 / 인셀덤 / incellderm',
#   'DOMAIN_NAME': 'https://01275.modoo.at/',
#   'TEL': '010-5629-9993',
#   'EMAIL': 'adwin9993@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-02-21',
#   'COM_ADDR': '서울특별시 송파구 송파대로 345 헬리오시티상가 지하1층 148-3호',
#   'STAT_NM': '광고용(홍보용)',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '코리아안전몰',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_4iaYvXyC1p',
#   'TEL': '확인안됨',
#   'EMAIL': 'kmk0831@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-02-13',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 티피씨인터넷',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'melikey.co',
#   'TEL': '02-585-1696/070-4128-1123',
#   'EMAIL': 'support@likey.to',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2019-11-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '리실버',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shop/mob_rYbzMJhnf',
#   'TEL': '확인안됨',
#   'EMAIL': 'kimiljune@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-26',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 위드어썸',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'withawesome.kr',
#   'TEL': '확인안됨',
#   'EMAIL': 'fortune1312@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-11-23',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '그로스스토어',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_3iw9Jq6y3w',
#   'TEL': '확인안됨',
#   'EMAIL': 'yoonsun0213_@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-15',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 아이피에이치씨',
#   'SHOP_NAME': '세계배꽃황실재단',
#   'DOMAIN_NAME': 'https://ihc.creatorlink.net/',
#   'TEL': '010-2294-0195',
#   'EMAIL': 'bankcd@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-09-08',
#   'COM_ADDR': '서울특별시 송파구 삼학사로 27 영미빌딩 (삼전동 182-2) 2층',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '포프',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_RgAHpMA6Hk',
#   'TEL': '확인안됨',
#   'EMAIL': 'mapleican@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-15',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '트렌드바이미 주식회사',
#   'SHOP_NAME': 'trend by me / 트렌드바이미 ',
#   'DOMAIN_NAME': 'trendbyme.co.kr',
#   'TEL': '02-2138-2343',
#   'EMAIL': 'jm.park@trendbyme.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 일반쇼핑몰',
#   'FIRST_HEO_DATE': '2023-11-09',
#   'COM_ADDR': '서울 서초구 방배로37길 50 M층(방배동, 희오빌딩)',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '3',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '3',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 화장품/향수',
#   'CHUNG': '가능',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 사업자등록번호 사이버몰이용약관 통신판매신고번호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '에스크로제도',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '있다',
#   'BAESONG': '소비자(반품택배비만 부담)',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '확인 안됨',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '워랩(War Lab)',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_8hFXQNf8Dv',
#   'TEL': '확인안됨',
#   'EMAIL': 'warlabkorea@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-01-08',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '(주)하이컨시 출판',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'www.sdijon.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'dbs9@hiconsy.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-02-26',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '롱런77',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops.mob_AHXtdttcBu',
#   'TEL': '확인안됨',
#   'EMAIL': 'zztt54117@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-12-22',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 코알라카르마',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'http://www.koalakarma.co.kr',
#   'TEL': '확인안됨',
#   'EMAIL': 'assarabia71@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-10-17',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '글로우무드',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_yLiGPugeGL',
#   'TEL': '확인안됨',
#   'EMAIL': 'alslgnzm@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '공구닷컴',
#   'SHOP_NAME': '공구/GONG9',
#   'DOMAIN_NAME': 'gong9.co.kr/',
#   'TEL': '02-545-9444',
#   'EMAIL': 'jullan10@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 일반쇼핑몰',
#   'FIRST_HEO_DATE': '2024-02-07',
#   'COM_ADDR': '서울특별시 서초구 강남대로 105길 12, 2층 4호 (잠원동, 금원빌딩)',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '3',
#   'DEAL_RATINGPOINT': '1',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 화장품/향수 건강용퓸/의료기기',
#   'CHUNG': '가능',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 기타',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '구매안전서비스없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '있다',
#   'BAESONG': '소비자(반품택배비만 부담)',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '늘품컨테이너',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_xgSRCftaCC',
#   'TEL': '확인안됨',
#   'EMAIL': 'neulpum97@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 헬로우랩 ',
#   'SHOP_NAME': '안녕,옥외광고/ hello,OOH ',
#   'DOMAIN_NAME': 'helloooh.co.kr',
#   'TEL': '070-7954-1804/1670-0930',
#   'EMAIL': 'contact@helloooh.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 청약유인',
#   'FIRST_HEO_DATE': '2023-11-28',
#   'COM_ADDR': '서울특별시 금천구 가산디지털1로 225, 1012호',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '3',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '3',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': '',
#   'CHUNG': '철회대상 품목 취급하지 않음',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등)',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '해당사항없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '해당사항 없음',
#   'BAESONG': '해당 없음',
#   'CLIENT_BBS': '있다(비공개)',
#   'LEAVE': '회원가입이 없다',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '이든에이',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_oCVFWB8UqH',
#   'TEL': '확인안됨',
#   'EMAIL': 'ii7942ii@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-09',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 핏커머스',
#   'SHOP_NAME': '메디핏커머스 / medifit commerce',
#   'DOMAIN_NAME': 'https://medifit.kr/',
#   'TEL': '070-5102-1390/02-2051-8283',
#   'EMAIL': 'fitcommerce@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-02-01',
#   'COM_ADDR': '서울특별시 서초구 서초대로75길 36 대청빌딩 3층',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '해피온비하우스',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_YAukJjBMV6',
#   'TEL': '확인안됨',
#   'EMAIL': '1009heb@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-01-04',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '엘티컨설팅 주식회사',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'http://lawrex.co.kr',
#   'TEL': '확인안됨',
#   'EMAIL': 'bdy@lawtimes.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-12-04',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '링클이네',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_HNwUuWK8NB',
#   'TEL': '확인안됨',
#   'EMAIL': 'as07001@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-09',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 비엠스테이지',
#   'SHOP_NAME': '패스룸 루푸 / pethroom loo poo',
#   'DOMAIN_NAME': 'https://pethroomcare.com/',
#   'TEL': '1533-9288',
#   'EMAIL': 'pethroom.care@bmstage.in',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-02-24',
#   'COM_ADDR': '서울특별시 강남구 테헤란로44길 8 11층',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '메유마(Makeup Your Mind)',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_xnTKFKFwQ1',
#   'TEL': '확인안됨',
#   'EMAIL': 'muym2022@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-11-24',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
# ...
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '디엘파크 주식회사',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'www.thelpark.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'glory2wide@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-12-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '오브콜스',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_xfSELv3eSt',
#   'TEL': '확인안됨',
#   'EMAIL': 'ofcourse93700@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-10-10',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '9cuve',
#   'SHOP_NAME': '9cuve / 나인큐브 ',
#   'DOMAIN_NAME': '9cuve.com',
#   'TEL': '070-7520-4999',
#   'EMAIL': '9cuve@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 일반쇼핑몰',
#   'FIRST_HEO_DATE': '2023-09-13',
#   'COM_ADDR': '확인안됨 ',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '1',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '1',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '1',
#   'SERVICE': ' 신발/가방/패션잡화/귀금속',
#   'CHUNG': '가능하나 일부품목제외, 기간축소',
#   'CHOGI': ' 상호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면이외에 표시(초기화면 미표시, 이용약관에 표시)',
#   'PER_INFO': '',
#   'DEAL_CARE': '에스크로제도',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '있다',
#   'BAESONG': '소비자(반품택배비만 부담)',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 불가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '째앰직구',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_spq5111qjX',
#   'TEL': '확인안됨',
#   'EMAIL': 'qerten@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '어반글로리',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_rWFfb8KkFa',
#   'TEL': '확인안됨',
#   'EMAIL': 'ubglory36@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-03-27',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '스마트쇼핑몰',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_ZmbSKE4tHm',
#   'TEL': '확인안됨',
#   'EMAIL': 'donguk08.kim@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '케이위더스(주)',
#   'SHOP_NAME': '케이위더스 / kwithus',
#   'DOMAIN_NAME': 'https://k-withus.kr/',
#   'TEL': '02-2282-2782/010-3137-2782/055-786-7999',
#   'EMAIL': 'kwithusceo@kwithus.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-12-05',
#   'COM_ADDR': '서울특별시 서초구 강남대로 216(양재플라자빌딩), 1층 1호',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '프레쉬함',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_QT9mWEPmjQ',
#   'TEL': '확인안됨',
#   'EMAIL': 'hamso08@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '차홍룸 반포점',
#   'SHOP_NAME': 'chahongroom/ 차홍룸 반포점 (네이버 예약 입점)',
#   'DOMAIN_NAME': 'https://booking.naver.com/booking/13/bizes/1004427',
#   'TEL': '02-533-2337',
#   'EMAIL': 'chbanpo@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 오픈마켓',
#   'FIRST_HEO_DATE': '2023-10-20',
#   'COM_ADDR': '서울특별시 서초구 반포동 1-1, 2층 238호~240호',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '1',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '1',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 예매.예약서비스',
#   'CHUNG': '가능하나 일부품목제외, 기간축소',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 사업자등록번호 사이버몰이용약관 호스팅 사업자',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰 기타',
#   'PYOJUN': '자체약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '해당사항없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '해당사항 없음',
#   'BAESONG': '해당 없음',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 퍼팩토리',
#   'SHOP_NAME': '픽셈 / FIXEM',
#   'DOMAIN_NAME': 'https://perfactory888.cafe24.com',
#   'TEL': '1577-1523/02-539-0932',
#   'EMAIL': 'perfactory88@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-10-16',
#   'COM_ADDR': '서울특별시 강남구 봉은사로 454 금탁타워 4층 2호',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '무니그래비',
#   'SHOP_NAME': '무니그래비/munigrabby',
#   'DOMAIN_NAME': 'munigrabby.cafe24.com',
#   'TEL': '02-6953-0301',
#   'EMAIL': 'mini@maven-d.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 일반쇼핑몰',
#   'FIRST_HEO_DATE': '2024-05-27',
#   'COM_ADDR': '서울특별시 서초구 서초대로 398, BNK디지털타워 5층 551호 (서초동)',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '2',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '1',
#   'DEAL_RATINGPOINT': '3',
#   'PYOJUN_RATINGPOINT': '3',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 의류 신발/가방/패션잡화/귀금속',
#   'CHUNG': '가능하나 일부품목제외, 기간축소',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 사업자등록번호 사이버몰이용약관 통신판매신고번호 호스팅 사업자',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰 기타',
#   'PYOJUN': '표준약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '에스크로제도',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '있다',
#   'BAESONG': '소비자(왕복택배비 부담)',
#   'CLIENT_BBS': '있다(공개)',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '코너스톤크리에이티브',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_xB2oVfJFN',
#   'TEL': '확인안됨',
#   'EMAIL': 'study@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-11-23',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '(주)힐링스쿨',
#   'SHOP_NAME': '힐링스쿨 원격교육원 / 힐링스쿨 / healingschool',
#   'DOMAIN_NAME': 'www.ihealingschool.co.kr',
#   'TEL': '070-4898-1698',
#   'EMAIL': 'myhealings@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2023-12-19',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '오풀웰니스(ofull wellness)',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_jMHFDsLF9J',
#   'TEL': '확인안됨',
#   'EMAIL': 'ofull@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '주식회사 하입앤컴퍼니',
#   'SHOP_NAME': '하입앤/hypen',
#   'DOMAIN_NAME': 'https://www.hypen.im/',
#   'TEL': '02-2135-4992',
#   'EMAIL': 'help@hypencorp.com',
#   'UPJONG_NBR': '',
#   'YPFORM': ' 중개',
#   'FIRST_HEO_DATE': '2024-02-16',
#   'COM_ADDR': '서울 서초구 강남대로 373 홍우빌딩 16층',
#   'STAT_NM': '영업중',
#   'TOT_RATINGPOINT': '1',
#   'CHOGI_RATINGPOINT': '2',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '1',
#   'PYOJUN_RATINGPOINT': '1',
#   'SECURITY_RATINGPOINT': '3',
#   'SERVICE': ' 가구/생활/주방 기타',
#   'CHUNG': '아무런 표시 없음',
#   'CHOGI': ' 상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호',
#   'GYULJE': ' 현금입금(무통장,계좌이체등) 신용카드 간편결제',
#   'PYOJUN': '자체약관 사용',
#   'P_INFO_CARE': '초기화면표시',
#   'PER_INFO': '',
#   'DEAL_CARE': '구매안전서비스없음',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '없다',
#   'BAESONG': '부담자 알 수 없음',
#   'CLIENT_BBS': '게시판 없음',
#   'LEAVE': '회원탈퇴 가능',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '로퍼프 ROPUF',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_z4LbsP95Ng',
#   'TEL': '확인안됨',
#   'EMAIL': 'prive2004@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-09',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '최강해에듀온라인원격교습학원',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'choiganghaeedu.com',
#   'TEL': '확인안됨',
#   'EMAIL': 'jjh6052003@nate.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-02-06',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '애드플라워',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_uaZaiFU7rY',
#   'TEL': '확인안됨',
#   'EMAIL': 'pretty3065@naver.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-12',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '선대인경제연구소',
#   'SHOP_NAME': '에스디인사이트 / SDinsight / 선대인교육아카데미',
#   'DOMAIN_NAME': 'www.sdinsight.co.kr',
#   'TEL': '070-7584-2050',
#   'EMAIL': 'master@sdinsight.co.kr',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2014-11-21',
#   'COM_ADDR': '경기도 양평군 남한강변길 209, 2층',
#   'STAT_NM': '휴업중',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'},
#  {'COMPANY': '구대1등장사장22',
#   'SHOP_NAME': '확인안됨',
#   'DOMAIN_NAME': 'https://buy.tosspayments.com/shops/mob_G6KwZMHV9b',
#   'TEL': '확인안됨',
#   'EMAIL': 'no1.ceo.jang1@gmail.com',
#   'UPJONG_NBR': '',
#   'YPFORM': '',
#   'FIRST_HEO_DATE': '2024-04-11',
#   'COM_ADDR': '확인안됨',
#   'STAT_NM': '사이트운영중단',
#   'TOT_RATINGPOINT': '0',
#   'CHOGI_RATINGPOINT': '0',
#   'CHUNG_RATINGPOINT': '0',
#   'DEAL_RATINGPOINT': '0',
#   'PYOJUN_RATINGPOINT': '0',
#   'SECURITY_RATINGPOINT': '0',
#   'SERVICE': '',
#   'CHUNG': '',
#   'CHOGI': '',
#   'GYULJE': '',
#   'PYOJUN': '',
#   'P_INFO_CARE': '',
#   'PER_INFO': '',
#   'DEAL_CARE': '',
#   'SSL_YN': '',
#   'INJEUNG': '',
#   'BAESONG_YEJEONG': '',
#   'BAESONG': '',
#   'CLIENT_BBS': '',
#   'LEAVE': '',
#   'KAESOL_YEAR': '',
#   'REG_DATE': '2024-11-25'}]

# %%
# json file 형식을 dataframe 으로 받아주기
raw1 = pd.DataFrame(response['ServiceInternetShopInfo']['row'])
raw1.head()
# Out:
#          COMPANY            SHOP_NAME  \
# 0  주식회사 에자일몽키테니스                 확인안됨
# 1          코즈믹크루  코즈믹크루 / cosmic crew
# 2             꿈틀                 확인안됨
# 3         리지필라테스   리지필라테스 (네이버 예약 입점)
# 4             호작                 확인안됨
#
#                                          DOMAIN_NAME            TEL  \
# 0                           http://www.rocktennis.kr   02-2135-2791
# 1          https://instashop.srookpay.com/cosmiccrew  010-5588-2560
# 2  https://buy.tosspayments.com/shops/mob_Zz5oaRpcvp           확인안됨
# 3  https://booking.naver.com/booking/13/bizes/747049  010-8074-8811
# 4                      https://buy.tosspayments.com/           확인안됨
#
#                           EMAIL UPJONG_NBR YPFORM FIRST_HEO_DATE  \
# 0          parking456@gmail.com                       2023-09-07
# 1  cosmiccrewbusiness@gmail.com                       2023-09-11
# 2        impressives2@naver.com                       2024-04-08
# 3             bomsoft@gmail.com              오픈마켓     2023-10-27
# 4            lugere22@gmail.com                       2024-06-27
#
#                        COM_ADDR  STAT_NM  ... PER_INFO DEAL_CARE SSL_YN  \
# 0                          확인안됨  사이트운영중단  ...
# 1  서울특별시 강남구 선릉로112길 21-4, 202호      휴업중  ...
# 2                          확인안됨  사이트운영중단  ...
# 3          서울특별시 서초구 서래로 39, 5층      영업중  ...             해당사항없음
# 4                          확인안됨  사이트운영중단  ...
#
#   INJEUNG BAESONG_YEJEONG BAESONG CLIENT_BBS    LEAVE KAESOL_YEAR    REG_DATE
# 0                                                                  2024-11-26
# 1                                                                  2024-11-26
# 2                                                                  2024-11-26
# 3                 해당사항 없음   해당 없음     있다(공개)  회원탈퇴 가능              2024-11-26
# 4                                                                  2024-11-26
#
# [5 rows x 32 columns]

# %%
raw1.T
# Out:
#                                             0   \
# COMPANY                          주식회사 에자일몽키테니스
# SHOP_NAME                                 확인안됨
# DOMAIN_NAME           http://www.rocktennis.kr
# TEL                               02-2135-2791
# EMAIL                     parking456@gmail.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                      2023-09-07
# COM_ADDR                                  확인안됨
# STAT_NM                                사이트운영중단
# TOT_RATINGPOINT                              0
# CHOGI_RATINGPOINT                            0
# CHUNG_RATINGPOINT                            0
# DEAL_RATINGPOINT                             0
# PYOJUN_RATINGPOINT                           0
# SECURITY_RATINGPOINT                         0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                            2024-11-26
#
#                                                              1   \
# COMPANY                                                   코즈믹크루
# SHOP_NAME                                   코즈믹크루 / cosmic crew
# DOMAIN_NAME           https://instashop.srookpay.com/cosmiccrew
# TEL                                               010-5588-2560
# EMAIL                              cosmiccrewbusiness@gmail.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                       2023-09-11
# COM_ADDR                           서울특별시 강남구 선릉로112길 21-4, 202호
# STAT_NM                                                     휴업중
# TOT_RATINGPOINT                                               0
# CHOGI_RATINGPOINT                                             0
# CHUNG_RATINGPOINT                                             0
# DEAL_RATINGPOINT                                              0
# PYOJUN_RATINGPOINT                                            0
# SECURITY_RATINGPOINT                                          0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                             2024-11-26
#
#                                                                      2   \
# COMPANY                                                              꿈틀
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_Zz5oaRpcvp
# TEL                                                                확인안됨
# EMAIL                                            impressives2@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-08
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-26
#
#                                                                      3   \
# COMPANY                                                          리지필라테스
# SHOP_NAME                                            리지필라테스 (네이버 예약 입점)
# DOMAIN_NAME           https://booking.naver.com/booking/13/bizes/747049
# TEL                                                       010-8074-8811
# EMAIL                                                 bomsoft@gmail.com
# UPJONG_NBR
# YPFORM                                                             오픈마켓
# FIRST_HEO_DATE                                               2023-10-27
# COM_ADDR                                           서울특별시 서초구 서래로 39, 5층
# STAT_NM                                                             영업중
# TOT_RATINGPOINT                                                       2
# CHOGI_RATINGPOINT                                                     2
# CHUNG_RATINGPOINT                                                     1
# DEAL_RATINGPOINT                                                      3
# PYOJUN_RATINGPOINT                                                    1
# SECURITY_RATINGPOINT                                                  3
# SERVICE
# CHUNG                                                 가능하나 일부품목제외, 기간축소
# CHOGI                          상호 대표자 소재지 전화번호 사업자등록번호 사이버몰이용약관 호스팅 사업자
# GYULJE                                 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰 기타
# PYOJUN                                                          자체약관 사용
# P_INFO_CARE                                                      초기화면표시
# PER_INFO
# DEAL_CARE                                                        해당사항없음
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG                                                 해당사항 없음
# BAESONG                                                           해당 없음
# CLIENT_BBS                                                       있다(공개)
# LEAVE                                                           회원탈퇴 가능
# KAESOL_YEAR
# REG_DATE                                                     2024-11-26
#
#                                                  4   \
# COMPANY                                          호작
# SHOP_NAME                                      확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/
# TEL                                            확인안됨
# EMAIL                            lugere22@gmail.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                           2024-06-27
# COM_ADDR                                       확인안됨
# STAT_NM                                     사이트운영중단
# TOT_RATINGPOINT                                   0
# CHOGI_RATINGPOINT                                 0
# CHUNG_RATINGPOINT                                 0
# DEAL_RATINGPOINT                                  0
# PYOJUN_RATINGPOINT                                0
# SECURITY_RATINGPOINT                              0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                 2024-11-26
#
#                                                                      5   \
# COMPANY                                                           시안홀딩스
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_7mDFpiTmCU
# TEL                                                                확인안됨
# EMAIL                                                  ajh117@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-09
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-26
#
#                                                       6   \
# COMPANY                                              대기업
# SHOP_NAME                                           확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops
# TEL                                                 확인안됨
# EMAIL                                 daein304@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                2024-04-12
# COM_ADDR                                            확인안됨
# STAT_NM                                          사이트운영중단
# TOT_RATINGPOINT                                        0
# CHOGI_RATINGPOINT                                      0
# CHUNG_RATINGPOINT                                      0
# DEAL_RATINGPOINT                                       0
# PYOJUN_RATINGPOINT                                     0
# SECURITY_RATINGPOINT                                   0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                      2024-11-26
#
#                                          7   \
# COMPANY                          주식회사 브라보헬스
# SHOP_NAME                              확인안됨
# DOMAIN_NAME           www.bravoinhealth.com
# TEL                                    확인안됨
# EMAIL                 ceo@bravoinhealth.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                   2023-09-11
# COM_ADDR                               확인안됨
# STAT_NM                             사이트운영중단
# TOT_RATINGPOINT                           0
# CHOGI_RATINGPOINT                         0
# CHUNG_RATINGPOINT                         0
# DEAL_RATINGPOINT                          0
# PYOJUN_RATINGPOINT                        0
# SECURITY_RATINGPOINT                      0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                         2024-11-26
#
#                                                                      8   \
# COMPANY                                                            살랑살랑
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_4ftjsAQ2Vw
# TEL                                                                확인안됨
# EMAIL                                               serini002@gmail.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-11
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-26
#
#                                                                      9   ...  \
# COMPANY                                                       사적인 공간 해서  ...
# SHOP_NAME                        쏘댓 스튜디오 / sothat_studio(네이버 스마트스토어 입점)  ...
# DOMAIN_NAME                  https://smartstore.naver.com/sothat_studio  ...
# TEL                                                       010-8802-9389  ...
# EMAIL                                                  ksreum@naver.com  ...
# UPJONG_NBR                                                               ...
# YPFORM                                                             오픈마켓  ...
# FIRST_HEO_DATE                                               2023-12-13  ...
# COM_ADDR                                       서울특별시 구로구 경인로35길 16-4 4층  ...
# STAT_NM                                                             영업중  ...
# TOT_RATINGPOINT                                                       3  ...
# CHOGI_RATINGPOINT                                                     3  ...
# CHUNG_RATINGPOINT                                                     3  ...
# DEAL_RATINGPOINT                                                      3  ...
# PYOJUN_RATINGPOINT                                                    3  ...
# SECURITY_RATINGPOINT                                                  3  ...
# SERVICE                                                        가구/생활/주방  ...
# CHUNG                                                                가능  ...
# CHOGI                  상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신...  ...
# GYULJE                                 현금입금(무통장,계좌이체등) 신용카드 간편결제 상품권 기타  ...
# PYOJUN                                                          표준약관 사용  ...
# P_INFO_CARE                                                      초기화면표시  ...
# PER_INFO                                                                 ...
# DEAL_CARE                                                        에스크로제도  ...
# SSL_YN                                                                   ...
# INJEUNG                                                                  ...
# BAESONG_YEJEONG                                                      있다  ...
# BAESONG                                                   소비자(왕복택배비 부담)  ...
# CLIENT_BBS                                                       있다(공개)  ...
# LEAVE                                                           회원탈퇴 가능  ...
# KAESOL_YEAR                                                              ...
# REG_DATE                                                     2024-11-26  ...
#
#                                                                      90  \
# COMPANY                                                           무니그래비
# SHOP_NAME                                              무니그래비/munigrabby
# DOMAIN_NAME                                       munigrabby.cafe24.com
# TEL                                                        02-6953-0301
# EMAIL                                                mini@maven-d.co.kr
# UPJONG_NBR
# YPFORM                                                            일반쇼핑몰
# FIRST_HEO_DATE                                               2024-05-27
# COM_ADDR                     서울특별시 서초구 서초대로 398, BNK디지털타워 5층 551호 (서초동)
# STAT_NM                                                             영업중
# TOT_RATINGPOINT                                                       2
# CHOGI_RATINGPOINT                                                     2
# CHUNG_RATINGPOINT                                                     1
# DEAL_RATINGPOINT                                                      3
# PYOJUN_RATINGPOINT                                                    3
# SECURITY_RATINGPOINT                                                  3
# SERVICE                                               의류 신발/가방/패션잡화/귀금속
# CHUNG                                                 가능하나 일부품목제외, 기간축소
# CHOGI                  상호 대표자 소재지 전화번호 사업자등록번호 사이버몰이용약관 통신판매신고번호 호스팅...
# GYULJE                                 현금입금(무통장,계좌이체등) 신용카드 간편결제 휴대폰 기타
# PYOJUN                                                          표준약관 사용
# P_INFO_CARE                                                      초기화면표시
# PER_INFO
# DEAL_CARE                                                        에스크로제도
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG                                                      있다
# BAESONG                                                   소비자(왕복택배비 부담)
# CLIENT_BBS                                                       있다(공개)
# LEAVE                                                           회원탈퇴 가능
# KAESOL_YEAR
# REG_DATE                                                     2024-11-25
#
#                                                                     91  \
# COMPANY                                                     코너스톤크리에이티브
# SHOP_NAME                                                         확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_xB2oVfJFN
# TEL                                                               확인안됨
# EMAIL                                                  study@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                              2023-11-23
# COM_ADDR                                                          확인안됨
# STAT_NM                                                        사이트운영중단
# TOT_RATINGPOINT                                                      0
# CHOGI_RATINGPOINT                                                    0
# CHUNG_RATINGPOINT                                                    0
# DEAL_RATINGPOINT                                                     0
# PYOJUN_RATINGPOINT                                                   0
# SECURITY_RATINGPOINT                                                 0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                    2024-11-25
#
#                                                      92  \
# COMPANY                                         (주)힐링스쿨
# SHOP_NAME             힐링스쿨 원격교육원 / 힐링스쿨 / healingschool
# DOMAIN_NAME                    www.ihealingschool.co.kr
# TEL                                       070-4898-1698
# EMAIL                              myhealings@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                               2023-12-19
# COM_ADDR                                           확인안됨
# STAT_NM                                             휴업중
# TOT_RATINGPOINT                                       0
# CHOGI_RATINGPOINT                                     0
# CHUNG_RATINGPOINT                                     0
# DEAL_RATINGPOINT                                      0
# PYOJUN_RATINGPOINT                                    0
# SECURITY_RATINGPOINT                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                     2024-11-25
#
#                                                                      93  \
# COMPANY                                           오풀웰니스(ofull wellness)
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_jMHFDsLF9J
# TEL                                                                확인안됨
# EMAIL                                                   ofull@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-11
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-25
#
#                                                                      94  \
# COMPANY                                                     주식회사 하입앤컴퍼니
# SHOP_NAME                                                     하입앤/hypen
# DOMAIN_NAME                                       https://www.hypen.im/
# TEL                                                        02-2135-4992
# EMAIL                                                help@hypencorp.com
# UPJONG_NBR
# YPFORM                                                               중개
# FIRST_HEO_DATE                                               2024-02-16
# COM_ADDR                                       서울 서초구 강남대로 373 홍우빌딩 16층
# STAT_NM                                                             영업중
# TOT_RATINGPOINT                                                       1
# CHOGI_RATINGPOINT                                                     2
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      1
# PYOJUN_RATINGPOINT                                                    1
# SECURITY_RATINGPOINT                                                  3
# SERVICE                                                     가구/생활/주방 기타
# CHUNG                                                         아무런 표시 없음
# CHOGI                  상호 대표자 소재지 전화번호 전자우편주소 사업자등록번호 사이버몰이용약관 통신판매신고번호
# GYULJE                                        현금입금(무통장,계좌이체등) 신용카드 간편결제
# PYOJUN                                                          자체약관 사용
# P_INFO_CARE                                                      초기화면표시
# PER_INFO
# DEAL_CARE                                                     구매안전서비스없음
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG                                                      없다
# BAESONG                                                      부담자 알 수 없음
# CLIENT_BBS                                                       게시판 없음
# LEAVE                                                           회원탈퇴 가능
# KAESOL_YEAR
# REG_DATE                                                     2024-11-25
#
#                                                                      95  \
# COMPANY                                                       로퍼프 ROPUF
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_z4LbsP95Ng
# TEL                                                                확인안됨
# EMAIL                                               prive2004@gmail.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-09
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-25
#
#                                        96  \
# COMPANY                    최강해에듀온라인원격교습학원
# SHOP_NAME                            확인안됨
# DOMAIN_NAME            choiganghaeedu.com
# TEL                                  확인안됨
# EMAIL                 jjh6052003@nate.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                 2024-02-06
# COM_ADDR                             확인안됨
# STAT_NM                           사이트운영중단
# TOT_RATINGPOINT                         0
# CHOGI_RATINGPOINT                       0
# CHUNG_RATINGPOINT                       0
# DEAL_RATINGPOINT                        0
# PYOJUN_RATINGPOINT                      0
# SECURITY_RATINGPOINT                    0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                       2024-11-25
#
#                                                                      97  \
# COMPANY                                                           애드플라워
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_uaZaiFU7rY
# TEL                                                                확인안됨
# EMAIL                                              pretty3065@naver.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-12
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-25
#
#                                                    98  \
# COMPANY                                      선대인경제연구소
# SHOP_NAME             에스디인사이트 / SDinsight / 선대인교육아카데미
# DOMAIN_NAME                       www.sdinsight.co.kr
# TEL                                     070-7584-2050
# EMAIL                          master@sdinsight.co.kr
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                             2014-11-21
# COM_ADDR                        경기도 양평군 남한강변길 209, 2층
# STAT_NM                                           휴업중
# TOT_RATINGPOINT                                     0
# CHOGI_RATINGPOINT                                   0
# CHUNG_RATINGPOINT                                   0
# DEAL_RATINGPOINT                                    0
# PYOJUN_RATINGPOINT                                  0
# SECURITY_RATINGPOINT                                0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                   2024-11-25
#
#                                                                      99
# COMPANY                                                       구대1등장사장22
# SHOP_NAME                                                          확인안됨
# DOMAIN_NAME           https://buy.tosspayments.com/shops/mob_G6KwZMHV9b
# TEL                                                                확인안됨
# EMAIL                                           no1.ceo.jang1@gmail.com
# UPJONG_NBR
# YPFORM
# FIRST_HEO_DATE                                               2024-04-11
# COM_ADDR                                                           확인안됨
# STAT_NM                                                         사이트운영중단
# TOT_RATINGPOINT                                                       0
# CHOGI_RATINGPOINT                                                     0
# CHUNG_RATINGPOINT                                                     0
# DEAL_RATINGPOINT                                                      0
# PYOJUN_RATINGPOINT                                                    0
# SECURITY_RATINGPOINT                                                  0
# SERVICE
# CHUNG
# CHOGI
# GYULJE
# PYOJUN
# P_INFO_CARE
# PER_INFO
# DEAL_CARE
# SSL_YN
# INJEUNG
# BAESONG_YEJEONG
# BAESONG
# CLIENT_BBS
# LEAVE
# KAESOL_YEAR
# REG_DATE                                                     2024-11-25
#
# [32 rows x 100 columns]
