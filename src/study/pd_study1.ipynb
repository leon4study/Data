# %%
import pandas as pd
from faker import Faker

# %%
fake = Faker()
data = []

# %%
for _ in range(10):
    person = {
        'Name': fake.name(),
        'Address': fake.address(),
        'Email': fake.email(),
        'Phone': fake.phone_number(),
        'Job': fake.job(),
        'Age': fake.random_int(min=18, max = 65)
    }
    data.append(person)

# %%
df = pd.DataFrame(data)

# %%
df.head(4)
# Out:
#               Name                                            Address  \
# 0    Richard Johns   69000 Smith Mall Suite 087\nBlakeville, NH 61449
# 1  Ronnie Williams  5892 Nicole Plaza Suite 747\nNorth Lisaland, D...
# 2      Holly Young      647 Matthew Trafficway\nFletcherton, FL 93164
# 3    Ryan Anderson       65167 Jackson Cliffs\nNorth Lauren, MD 54518
#
#                         Email                   Phone  \
# 0   charleshudson@example.org            913-705-2450
# 1  joshuawilliams@example.net      887-571-5902x90359
# 2        joseph34@example.com              5317901443
# 3        nathan12@example.org  001-966-619-0805x04905
#
#                                      Job  Age
# 0               Educational psychologist   40
# 1                    Call centre manager   45
# 2                 Holiday representative   53
# 3  Emergency planning/management officer   58

# %%
df["Name"]
# Out:
# 0      Richard Johns
# 1    Ronnie Williams
# 2        Holly Young
# 3      Ryan Anderson
# 4     Crystal Fisher
# 5          Scott Kim
# 6      Brandon Reyes
# 7     Michael Morgan
# 8      Kirsten Brown
# 9          John Leon
# Name: Name, dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'Email', 'Phone', 'Job', 'Age'], dtype='object')

# %%
df.columns = ['Name', '주소', 'Email', 'Phone', 'Job','Age']
df.head(3)
# Out:
#               Name                                                 주소  \
# 0    Richard Johns   69000 Smith Mall Suite 087\nBlakeville, NH 61449
# 1  Ronnie Williams  5892 Nicole Plaza Suite 747\nNorth Lisaland, D...
# 2      Holly Young      647 Matthew Trafficway\nFletcherton, FL 93164
#
#                         Email               Phone                       Job  \
# 0   charleshudson@example.org        913-705-2450  Educational psychologist
# 1  joshuawilliams@example.net  887-571-5902x90359       Call centre manager
# 2        joseph34@example.com          5317901443    Holiday representative
#
#    Age
# 0   40
# 1   45
# 2   53

# %%
df = df.rename(columns={'주소' : 'address'})
df.head(4)
# Out:
#               Name                                            address  \
# 0    Richard Johns   69000 Smith Mall Suite 087\nBlakeville, NH 61449
# 1  Ronnie Williams  5892 Nicole Plaza Suite 747\nNorth Lisaland, D...
# 2      Holly Young      647 Matthew Trafficway\nFletcherton, FL 93164
# 3    Ryan Anderson       65167 Jackson Cliffs\nNorth Lauren, MD 54518
#
#                         Email                   Phone  \
# 0   charleshudson@example.org            913-705-2450
# 1  joshuawilliams@example.net      887-571-5902x90359
# 2        joseph34@example.com              5317901443
# 3        nathan12@example.org  001-966-619-0805x04905
#
#                                      Job  Age
# 0               Educational psychologist   40
# 1                    Call centre manager   45
# 2                 Holiday representative   53
# 3  Emergency planning/management officer   58

# %%
del df['Phone']
df.head(4)
# Out:
#               Name                                            address  \
# 0    Richard Johns   69000 Smith Mall Suite 087\nBlakeville, NH 61449
# 1  Ronnie Williams  5892 Nicole Plaza Suite 747\nNorth Lisaland, D...
# 2      Holly Young      647 Matthew Trafficway\nFletcherton, FL 93164
# 3    Ryan Anderson       65167 Jackson Cliffs\nNorth Lauren, MD 54518
#
#                         Email                                    Job  Age
# 0   charleshudson@example.org               Educational psychologist   40
# 1  joshuawilliams@example.net                    Call centre manager   45
# 2        joseph34@example.com                 Holiday representative   53
# 3        nathan12@example.org  Emergency planning/management officer   58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     10 non-null     object
#  1   address  10 non-null     object
#  2   Email    10 non-null     object
#  3   Job      10 non-null     object
#  4   Age      10 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes

# %%
df1 = pd.DataFrame(
    {
        'A' : [1,2,3,4],
        'B' : [5,6,7,None]
    }
)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       3 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 196.0 bytes

# %%
df1.isna()
# Out:
#        A      B
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False   True

# %%
df1[df1['B'].isna()]
# Out:
#    A   B
# 3  4 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     10 non-null     object
#  1   address  10 non-null     object
#  2   Email    10 non-null     object
#  3   Job      10 non-null     object
#  4   Age      10 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes

# %%
#df['Age'] = df['Age'].astype(str)
df['Age'] = df['Age'].astype(int)

# %%
df.loc[0:1]
# Out:
#               Name                                            address  \
# 0    Richard Johns   69000 Smith Mall Suite 087\nBlakeville, NH 61449
# 1  Ronnie Williams  5892 Nicole Plaza Suite 747\nNorth Lisaland, D...
#
#                         Email                       Job  Age
# 0   charleshudson@example.org  Educational psychologist   40
# 1  joshuawilliams@example.net       Call centre manager   45

# %%
df.iloc[2::2]
# Out:
#              Name                                            address  \
# 2     Holly Young      647 Matthew Trafficway\nFletcherton, FL 93164
# 4  Crystal Fisher  823 Miller Islands Suite 591\nWest Tamarafurt,...
# 6   Brandon Reyes  323 Casey Mountain Suite 680\nLake Dennis, CT ...
# 8   Kirsten Brown  18117 Raymond Orchard Apt. 110\nCostashire, NJ...
#
#                        Email                          Job  Age
# 2       joseph34@example.com       Holiday representative   53
# 4       robert34@example.net            Systems developer   64
# 6       rhonda68@example.net  Passenger transport manager   35
# 8  taylorrichard@example.org                 Youth worker   32

# %%
df = pd.DataFrame(
    {
        'A' : [1,2,3,4],
        'B' : [5,6,7,None],
        'C' : [100,200,300,400]
    }, index=['a','b','c','d']
)

df
# Out:
#    A    B    C
# a  1  5.0  100
# b  2  6.0  200
# c  3  7.0  300
# d  4  NaN  400

# %%
df.loc['a'], df.iloc[1]
# Out:
# (A      1.0
#  B      5.0
#  C    100.0
#  Name: a, dtype: float64,
#  A      2.0
#  B      6.0
#  C    200.0
#  Name: b, dtype: float64)

# %%
df.loc['b':'d', 'A':'B']
# Out:
#    A    B
# b  2  6.0
# c  3  7.0
# d  4  NaN

# %%
df.loc[:,'A']
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: A, dtype: int64

# %%
df['A']
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: A, dtype: int64

# %%
df['A','B']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/leo4study/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('A', 'B')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['A','B']
#
# ...

# %%
df[['B','A']]
# Out:
#      B  A
# a  5.0  1
# b  6.0  2
# c  7.0  3
# d  NaN  4

# %%
df.loc['b': , ['C','A']]
# Out:
#      C  A
# b  200  2
# c  300  3
# d  400  4

# %%
import seaborn as sns
data = sns.load_dataset('tips')

# %%
import os
path = os.getcwd()
path
# Out:
# '/Users/jun/GitStudy/Data_4/src/study'

# %%
data_path = os.path.join(path, 'data')
data_path
# Out:
# '/Users/jun/GitStudy/Data_4/src/study/data'

# %%
if not os.path.exists(data_path):
    os.mkdir(data_path)
os.chdir('data')

# %%
data.to_csv('tips.csv', index = False )

# %%
data = pd.read_csv('tips.csv')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data[(data['sex']=='Male') & (data['smoker'] == 'Yes')].head(5)
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 56       38.01  3.00  Male    Yes  Sat  Dinner     4
# 58       11.24  1.76  Male    Yes  Sat  Dinner     2
# 60       20.29  3.21  Male    Yes  Sat  Dinner     2
# 61       13.81  2.00  Male    Yes  Sat  Dinner     2
# 62       11.02  1.98  Male    Yes  Sat  Dinner     2

# %%
data.loc[data['size']==3, 'total_bill':'sex'].head(4)
# Out:
#     total_bill   tip     sex
# 1        10.34  1.66    Male
# 2        21.01  3.50    Male
# 16       10.33  1.67  Female
# 17       16.29  3.71    Male

# %%
data[data['size'].isin([1,2])]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [160 rows x 7 columns]

# %%
data['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
data[data['day'].isin(['Fri'])].count()
# Out:
# total_bill    19
# tip           19
# sex           19
# smoker        19
# day           19
# time          19
# size          19
# dtype: int64

# %%
data[data['day'].isin(['Fri','Sat'])].count()
# Out:
# total_bill    106
# tip           106
# sex           106
# smoker        106
# day           106
# time          106
# size          106
# dtype: int64

# %%
condition =  data['tip'] < 2
condition
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
data[condition].head(10)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
# 30        9.55  1.45    Male     No  Sat  Dinner     2
# 43        9.68  1.32    Male     No  Sun  Dinner     2
# 53        9.94  1.56    Male     No  Sun  Dinner     2
# 57       26.41  1.50  Female     No  Sat  Dinner     2

# %%
cond1 = data['size'] >= 3
cond2 = data['tip'] < 2

data[cond1 & cond2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 146       18.64  1.36  Female     No  Thur   Lunch     3

# %%
cond = (data['sex'] == 'Female') & (data['tip'] > 3)
data[cond].head(4)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 18       16.97  3.50  Female     No  Sun  Dinner     3

# %%
data['created_at'] = '2024-01-01'
data
# Out:
#      total_bill   tip     sex smoker   day    time  size  created_at
# 0         16.99  1.01  Female     No   Sun  Dinner     2  2024-01-01
# 1         10.34  1.66    Male     No   Sun  Dinner     3  2024-01-01
# 2         21.01  3.50    Male     No   Sun  Dinner     3  2024-01-01
# 3         23.68  3.31    Male     No   Sun  Dinner     2  2024-01-01
# 4         24.59  3.61  Female     No   Sun  Dinner     4  2024-01-01
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  2024-01-01
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  2024-01-01
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  2024-01-01
# 242       17.82  1.75    Male     No   Sat  Dinner     2  2024-01-01
# 243       18.78  3.00  Female     No  Thur  Dinner     2  2024-01-01
#
# [244 rows x 8 columns]

# %%
data.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# created_at     object
# dtype: object

# %%
data['created_at'] = pd.to_datetime(data['created_at'])

# %%
data.dtypes
# Out:
# total_bill           float64
# tip                  float64
# sex                   object
# smoker                object
# day                   object
# time                  object
# size                   int64
# created_at    datetime64[ns]
# dtype: object

# %%
df1 = pd.DataFrame(
    {
        'A': ['A0', 'A1', 'A2'],
        'B': ['B0', 'B1', 'B2']
    }
)

df2 = pd.DataFrame(
    {
        'A': ['A3', 'A4', 'A5'], 
        'B': ['B3', 'B4', 'B5']
    }
)

# %%
pd.concat([df1, df2])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5

# %%
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   A   B
# 0  A0  B0  A3  B3
# 1  A1  B1  A4  B4
# 2  A2  B2  A5  B5

# %%
df3 = pd.DataFrame(
    {
        'A': ['A3', 'A4', 'A5'], 
        'B': ['B3', 'B4', 'B5'],
        'C': ['C3', 'C4', 'C5']
    }
)

# %%
pd.concat([df1,df3]).reset_index(drop=True)
# Out:
#     A   B    C
# 0  A0  B0  NaN
# 1  A1  B1  NaN
# 2  A2  B2  NaN
# 3  A3  B3   C3
# 4  A4  B4   C4
# 5  A5  B5   C5

# %%
left_df = pd.DataFrame({'key': ['A', 'B', 'C', 'D'], 'value': [1, 2, 3, 4]})
right_df = pd.DataFrame({'key': ['B', 'D', 'E', 'F'], 'value': [5, 6, 7, 8]})

# %%
merged_df = pd.merge(left_df, right_df, on= 'key') 
merged_df
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %%
pd.merge(left_df, right_df, on= 'key', how='outer')
# Out:
#   key  value_x  value_y
# 0   A      1.0      NaN
# 1   B      2.0      5.0
# 2   C      3.0      NaN
# 3   D      4.0      6.0
# 4   E      NaN      7.0
# 5   F      NaN      8.0

# %%
pd.merge(left_df, right_df, on='key', how='left')
# Out:
#   key  value_x  value_y
# 0   A        1      NaN
# 1   B        2      5.0
# 2   C        3      NaN
# 3   D        4      6.0

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
    'Value': [1, 2, 3, 4, 5, 6]
}
df = pd.DataFrame(data)
df
# Out:
#   Category  Value
# 0        A      1
# 1        B      2
# 2        A      3
# 3        B      4
# 4        A      5
# 5        B      6

# %%
df.groupby('Category')

# %%
df.groupby('Category').mean()#sum(),count(),max(),first()
# Out:
#           Value
# Category
# A           3.0
# B           4.0

# %% [markdown]
# #### python groupby agg 사용법 검색 필요

# %%
df.groupby('Category').agg(list)
# Out:
#               Value
# Category
# A         [1, 3, 5]
# B         [2, 4, 6]

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df[['day','total_bill','tip','size']].groupby('day').mean()
# Out:
#       total_bill       tip      size
# day
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105
# Thur   17.682742  2.771452  2.451613

# %%
df[['sex','day','total_bill','tip','size']].groupby(['day','sex']).mean()
# Out:
#              total_bill       tip      size
# day  sex
# Fri  Female   14.145556  2.781111  2.111111
#      Male     19.857000  2.693000  2.100000
# Sat  Female   19.680357  2.801786  2.250000
#      Male     20.802542  3.083898  2.644068
# Sun  Female   19.872222  3.367222  2.944444
#      Male     21.887241  3.220345  2.810345
# Thur Female   16.715312  2.575625  2.468750
#      Male     18.714667  2.980333  2.433333

# %%
df[['sex','day','total_bill','tip','size']].groupby(['day','sex']).agg({'total_bill':'max','tip':'mean', 'size':'sum'})
# Out:
#              total_bill       tip  size
# day  sex
# Fri  Female       22.75  2.781111    19
#      Male         40.17  2.693000    21
# Sat  Female       44.30  2.801786    63
#      Male         50.81  3.083898   156
# Sun  Female       35.26  3.367222    53
#      Male         48.17  3.220345   163
# Thur Female       43.11  2.575625    79
#      Male         41.19  2.980333    73

# %%
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-01'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 20, 30, 40, 50]
}
df = pd.DataFrame(data)

# %%
pivot = df.pivot_table(index='Date', columns='Category', values='Value',aggfunc='sum')
pivot
# Out:
# Category     A   B
# Date
# 2023-01-01  60  20
# 2023-01-02  30  40

# %%
df = pd.DataFrame({
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-01'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'SubCategory': ['X', 'X', 'Y', 'Y', 'X'],
    'Value': [10, 20, 30, 40, 50]
})
df
# Out:
#          Date Category SubCategory  Value
# 0  2023-01-01        A           X     10
# 1  2023-01-01        B           X     20
# 2  2023-01-02        A           Y     30
# 3  2023-01-02        B           Y     40
# 4  2023-01-01        A           X     50

# %%
pivot = df.pivot_table(index= 'Date', columns=['Category','SubCategory'],
                values= 'Value', aggfunc='sum')
pivot
# Out:
# Category        A           B
# SubCategory     X     Y     X     Y
# Date
# 2023-01-01   60.0   NaN  20.0   NaN
# 2023-01-02    NaN  30.0   NaN  40.0

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 22, 30, 18, 30],
    'Score': [85, 90, 75, 80, 95]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   22     90
# 2  Charlie   30     75
# 3    David   18     80
# 4      Eva   30     95

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#       Name  Age  Score
# 2  Charlie   30     75
# 4      Eva   30     95
# 0    Alice   25     85
# 1      Bob   22     90
# 3    David   18     80

# %%
df.sort_values(by=['Age','Score'], ascending=[True,False])
# Out:
#       Name  Age  Score
# 3    David   18     80
# 1      Bob   22     90
# 0    Alice   25     85
# 4      Eva   30     95
# 2  Charlie   30     75

# %%
df.sort_index(ascending=False)
# Out:
#       Name  Age  Score
# 4      Eva   30     95
# 3    David   18     80
# 2  Charlie   30     75
# 1      Bob   22     90
# 0    Alice   25     85

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pltKorean_mac as pm
pm.set_font_manager()
# Out:
# Using font: /Library/Fonts/Arial Unicode.ttf

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('한글')
plt.show()

# %%
import pandas as pd

# %%
data = {
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1]
}
df = pd.DataFrame(data)
df
# Out:
#    A  B
# 0  1  5
# 1  2  4
# 2  3  3
# 3  4  2
# 4  5  1

# %%
df.plot(x = 'A', y = 'B')
plt.show()

# %% [markdown]
# 3-2. 스타일 설정하기

# %%
df.plot(x = 'A', y= 'B', color = 'Green', linestyle= '--', marker ='o')
# Out:
# <Axes: xlabel='A'>

# %% [markdown]
# 3-3. 범례 추가

# %%
df.plot(x='A', y = 'B', color= 'red', linestyle='--',marker = 'o', label = 'Data series' )
# Out:
# <Axes: xlabel='A'>

# %%
ax = df.plot(x = 'A', y='B', color ='red', linestyle = '--', marker = 'o')
ax.legend(['Data Series'])
ax.set_xlabel('X-axis')
ax.text(4,3, 'Some Text', fontsize = 12)
ax.text(2,2, 'Some Text', fontsize = 10)
plt.show()

# %%
plt.figure(figsize=(12,6))
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(10,6))
ax = df.plot(x = 'A', y='B', color ='red', linestyle = '--', marker = 'o', ax = ax)
ax.legend(['Data Series'])
ax.set_xlabel('X-axis')
ax.set_title('Title')
ax.text(4,3, 'Some Text', fontsize = 12)
ax.text(2,2, 'Some Text', fontsize = 10)
plt.show()

# %% [markdown]
# # df.join(sufficce 옵션 잘 찾아보기!!!!)

# %% [markdown]
# # 04. 그래프 그리기- 차트
#
# 4-1 Line

# %%
import seaborn as sns
data = sns.load_dataset('flights')

# %%
import pandas as pd, matplotlib.pyplot as plt

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data[['year','passengers']].groupby('year').sum().rename(columns={'passengers':'sum_passengers'})
# Out:
#       sum_passengers
# year
# 1949            1520
# 1950            1676
# 1951            2042
# 1952            2364
# 1953            2700
# 1954            2867
# 1955            3408
# 1956            3939
# 1957            4421
# 1958            4572
# 1959            5140
# 1960            5714

# %%
data_grouped = data[['year','passengers']].groupby('year').sum().reset_index()
data_grouped
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
plt.plot(data_grouped['year'], data_grouped['passengers'])
plt.xlabel('year')
plt.ylabel('passengers')
# Out:
# Text(0, 0.5, 'passengers')

# %% [markdown]
# 4-2 Bar vs Histogram

# %%
data = {'도시': ['서울', '부산', '대구', '인천'],
        '인구': [990, 350, 250, 290]}
df = pd.DataFrame(data)
df
# Out:
#    도시   인구
# 0  서울  990
# 1  부산  350
# 2  대구  250
# 3  인천  290

# %%
import pltKorean_mac
pltKorean_mac.set_font_manager()

# %%
plt.bar(df['도시'], df['인구'])
plt.xlabel('city')
plt.ylabel('population')
plt.title('population of city')
plt.show()

# %%
import numpy as np

# %%
data =np.random.randn(100)
data.shape
# Out:
# (100,)

# %% [markdown]
# #bins 옵션은 히스토그램에서 데이터를 나누는 구간(bin)의 개수를 결정하는 역할을 합니다. bins=30이라고 설정하면, 데이터를 30개의 구간으로 나누어 각 구간에 속하는 데이터의 빈도수를 표시합니다

# %%
plt.hist(data, bins=30)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ## ⁉️ Bar vs Histogram 의 차이는 무엇인가요?

# %% [markdown]
# - 그래프 비교
#
# | 구분 | 막대 그래프 | 히스토그램 |
# | --- | --- | --- |
# | 데이터 유형 | 범주형 데이터 비교 | 연속적 데이터 분포 |
# | 막대 형태 | 수직 or 수평 막대 (크기) | 막대가 붙어있는 형태 (빈도) |
# | 시각화 유형  | 해당 범주의 크기를 나타냄 | X축은 데이터 값의 범위를, Y축은 해당 범위에서의 빈도를 나타냄 |
# | 예시 | 팀별 판매량, 국가별 GDP 등을 비교 | 시험 점수 분포, 온도 변화 등 연속적인 데이터의 분포 |
#
# - 데이터를 시각화하는 목적이 다른 그래프입니다.
# - 막대 그래프는 주로 범주형 데이터의 값을 비교하는데 사용되고, 히스토그램은 연속적인 데이터의 분포를 시각화하는 데 사용됩니다.

# %% [markdown]
# 4-3 Pie

# %%
sizes = [30, 20, 25, 15, 10]
labels = ['A', 'B', 'C', 'D', 'E']

# autopct = %d%% >> 소수점을 없애고 정수로 백분율 표시
plt.pie(sizes, labels = labels, autopct= '%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# 4-4 Box plot

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
species =  iris['species'].unique()

# %%
sepal_lengths_list = [iris[iris['species'] == s]['sepal_length'].tolist() for s in iris['species'].unique()] 
sepal_lengths_list
# Out:
# [[5.1,
#   4.9,
#   4.7,
#   4.6,
#   5.0,
#   5.4,
#   4.6,
#   5.0,
#   4.4,
#   4.9,
#   5.4,
#   4.8,
#   4.8,
#   4.3,
#   5.8,
#   5.7,
#   5.4,
#   5.1,
#   5.7,
#   5.1,
#   5.4,
#   5.1,
#   4.6,
#   5.1,
#   4.8,
#   5.0,
#   5.0,
#   5.2,
#   5.2,
#   4.7,
#   4.8,
#   5.4,
#   5.2,
#   5.5,
#   4.9,
#   5.0,
#   5.5,
#   4.9,
#   4.4,
#   5.1,
#   5.0,
#   4.5,
#   4.4,
#   5.0,
#   5.1,
#   4.8,
#   5.1,
#   4.6,
#   5.3,
#   5.0],
#  [7.0,
#   6.4,
#   6.9,
#   5.5,
#   6.5,
#   5.7,
#   6.3,
#   4.9,
#   6.6,
#   5.2,
#   5.0,
#   5.9,
#   6.0,
#   6.1,
#   5.6,
#   6.7,
#   5.6,
#   5.8,
#   6.2,
#   5.6,
#   5.9,
#   6.1,
#   6.3,
#   6.1,
#   6.4,
#   6.6,
#   6.8,
#   6.7,
#   6.0,
#   5.7,
#   5.5,
#   5.5,
#   5.8,
#   6.0,
#   5.4,
#   6.0,
#   6.7,
#   6.3,
#   5.6,
#   5.5,
#   5.5,
#   6.1,
#   5.8,
#   5.0,
#   5.6,
#   5.7,
#   5.7,
#   6.2,
#   5.1,
#   5.7],
#  [6.3,
#   5.8,
#   7.1,
#   6.3,
#   6.5,
#   7.6,
#   4.9,
#   7.3,
#   6.7,
#   7.2,
# ...

# %%
len(sepal_lengths_list[0])
# Out:
# 50

# %% [markdown]
# # Box Plot(박스 플롯)
#
# - 박스 플롯의 구성 요소:
#     1. **상자(Box):** 데이터의 중앙값과 사분위수(25%와 75%)를 나타냅니다. 상자의 아래쪽 끝은 25%의 값(1사분위수), 상자의 윗쪽 끝은 75%의 값(3사분위수)을 나타냅니다. 상자의 중앙에 위치한 선은 중앙값을 나타냅니다.
#     2. **수염(Whisker):** 상자의 위 아래로 연장되는 선으로, 일반적으로 1.5배의 사분위 범위로 계산되는데, 이 범위를 넘어가는 값은 이상치(outlier)로 간주됩니다. 수염의 끝은 최솟값과 최댓값을 나타냅니다.
#     3. **이상치(Outliers):** 수염 부분을 벗어나는 개별 데이터 포인트로, 일반적인 범위를 벗어나는 값들을 의미합니다. 이상치는 박스 플롯에서 독립적으로 표시됩니다.
# - 박스 플롯의 활용:
#     - 데이터의 분포와 중앙값, 이상치를 한눈에 파악할 수 있습니다.
#     - 다수의 그룹 또는 범주 간의 데이터 분포를 비교하는 데 유용합니다.
#     - 통계적으로 중요한 데이터의 특성을 시각적으로 표현할 때 활용됩니다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 위 그림은 박스 플롯의 예시입니다. 상자의 아래쪽 끝은 25%의 값(1사분위수), 상자의 윗쪽 끝은 75%의 값(3사분위수)을 나타냅니다. 중앙에 위치한 선은 중앙값을, 수염의 끝은 최솟값과 최댓값을 나타냅니다. 또한, 박스 플롯에서 이상치(outlier)로 간주되는 값들이 점으로 표시되어 있습니다

# %% [markdown]
# 중앙값
# - 데이터를 크기 순서대로 나열했을 때, 정확히 중간에 위치한 값입니다. 중앙값은 데이터의 중심 경향을 나타내는 하나의 지표로서 사용됩니다.
#
# - 중앙값은 데이터의 이상치에 대해 덜 민감하며, 데이터의 대표값을 파악하는 데에 사용됩니다.

# %% [markdown]
# 사분위수(quartiles)
# - 데이터를 4등분한 지점을 말합니다. 이것은 데이터를 크기 순서대로 정렬했을 때, 25%, 50%, 75%에 해당하는 위치의 값을 가리킵니다.

# %% [markdown]
# 이상치
# - 일반적으로 이상치는 상자 수염 그림(Box Plot)이나 히스토그램(Histogram) 등을 사용하여 시각적으로 확인될 수 있습니다. 또한, 통계적 방법이나 도메인 지식을 활용하여 이상치를 탐지하고 처리하는 방법도 있습니다.

# %%
plt.boxplot(sepal_lengths_list, labels = species)
plt.show()

# %%
sns.boxplot(x='species', y= 'sepal_length', data=iris)
plt.show()

# %% [markdown]
# # 4-5 Scatter
#
# - 산점도는 두 변수 간의 관계를 점으로 표시하여 보여주는 그래프입니다.
# - 두 변수 간의 상관 관계를 보여주고,
# 각 점이 데이터 포인트를 나타내며, 그 점들이 어떻게 분포되어 있는지 시각적으로 확인할 수 있습니다.
#     - **자료 유형:** 두 변수 간의 관계 및 상관관계를 보여줄 때 사용됩니다.
#     - **활용:** 변수 간의 관계, 군집, 이상치를 확인하고자 할 때 유용합니다.

# %%
plt.scatter(iris['petal_length'],iris['petal_width'])
plt.xlabel('Petal length')
plt.ylabel('Petal width')
# Out:
# Text(0, 0.5, 'Petal width')

# %%
plt.scatter(iris['sepal_length'],iris['sepal_width'])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
# corr 메서드 호출해보면 오류가 남. Stirng이라서 난 건데 에러메세지에는 
# String 값으로 상관계수를 나타내는데 제한되니까 에러가 발생.
# 해결 방법으로는 두가지. 한가지는 해당 데이터셋을 전처리해서 원하는 값으로 만들고 해당 메소드를 활요해서 상관성을 본다던가
# corr 메서드 내에서 nemeric_only 라는 값을 True로 설정하면 숫자 형태의 변수만 가지고 상관성 나타내겠다.
iris.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 5
#       1 # corr 메서드 호출해보면 오류가 남. Stirng이라서 난 건데 에러메세지에는
#       2 # String 값으로 상관계수를 나타내는데 제한되니까 에러가 발생.
#       3 # 해결 방법으로는 두가지. 한가지는 해당 데이터셋을 전처리해서 원하는 값으로 만들고 해당 메소드를 활요해서 상관성을 본다던가
#       4 # corr 메서드 내에서 nemeric_only 라는 값을 True로 설정하면 숫자 형태의 변수만 가지고 상관성 나타내겠다.
# ----> 5 iris.corr()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/leo4study/lib/python3.11/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
# petal_length / petal_width 높은 상관성이 있었다. 실제 그래프에서도 그랬었다.
iris.corr(numeric_only= True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 상관관계의 강도 확인하기
#
# 상관계수 계산: 피어슨 상관계수와 같은 통계적 방법을 사용하여 상관관계의 정도를 수치적으로 계산할 수 있습니다.

# %% [markdown]
# # 피어슨 상관계수란?
#
# - 피어슨 상관계수(Pearson correlation coefficient)는 두 변수 간의 선형적인 관계를 측정하기 위한 통계적인 방법 중 하나입니다. 주로 연속형 변수들 간의 상관관계를 평가하는 데 사용됩니다.
# - **피어슨 상관계수의 특징:**
#     - **범위:** -1에서 1 사이의 값을 가집니다.
#     - **양의 상관관계:** 1에 가까울수록 강한 양의 선형관계를 나타냅니다.
#     - **음의 상관관계:** -1에 가까울수록 강한 음의 선형관계를 나타냅니다.
#     - **무상관 관계:** 0에 가까울수록 선형관계가 거의 없거나 약한 관계를 가집니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 💡 피어슨 상관계수는,
# - r이 -1.0과 -0.7 사이이면, 강한 음적 선형관계,
# - r이 -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계,
# - r이 -0.3과 -0.1 사이이면, 약한 음적 선형관계,
# - r이 -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계,
# - r이 +0.1과 +0.3 사이이면, 약한 양적 선형관계,
# - r이 +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계,
# - r이 +0.7과 +1.0 사이이면, 강한 양적 선형관계

# %% [markdown]
# - 피어슨 상관계수는 **공분산**을 각 변수의 **표준편차**로 나누어 **정규화**한 값으로, **두 변수 간의 선형적 관계 정도를 측정**합니다. <u>값이 1에 가까울수록 두 변수 사이에 강한 선형적 관계가 있음을 의미하며, 값이 0에 가까울수록 두 변수 사이에 선형적인 관계가 거의 없거나 매우 약한 관계를 나타냅니다.</u>
#
# - 피어슨 상관계수는 **주로 선형적인 관계를 가진 두 변수 간의 상관성을 평가하는 데 사용**되며, 변수 간의 비선형적 관계는 잘 표현하지 못할 수 있습니다. 이상치가 있는 경우에도 영향을 받을 수 있습니다.
#
# - https://ko.wikipedia.org/wiki/%EC%83%81%EA%B4%80_%EB%B6%84%EC%84%9D#%ED%94%BC%EC%96%B4%EC%8A%A8_%EC%83%81%EA%B4%80_%EA%B3%84%EC%88%98

# %% [markdown]
# <aside>
# 💡 [ **매출과 광고 비용 간의 상관분석 예시 ]**
#
# 최근 신제품 출시를 고려하고 있는 A회사가 있다고 가정해봅시다.
# 마케팅 예산을 산정하기 위해, 이전 판매 데이터와 마케팅 비용 간의 관계를 알고자 합니다.
#
# A회사의 특정기간의 판매 데이터와 마케팅 비용 데이터를 활용하여 상관분석한 결과,
#
# - 상관관계수가 약 0.85로 매우 높은 양의 상관관계를 확인했습니다.
# - 즉, 마케팅 비용이 증가할수록 매출도 상승하는 경향이 있습니다.
#
# 위 분석내용을 기반으로,
#
# - 새 제품 출시 시 마케팅 예산을 늘릴 경우, 매출 증가가 어느정도 상관성이 존재한다라고 판단하여 마케팅 예산을 투입해 매출 상승을 기대하였음.
# - 단, 상관관계가 인과관계를 의미하지는 않는다는 점 유의할 것.
#
# 이처럼, 상관분석은 비즈니스에서 전략적인 의사 결정에 중요한 도움을 주는 도구로 활용될 수 있습니다.
#
# </aside>

# %% [markdown]
# ## 간단한 용어 설명
#
# 표준편차
# - 표준편차(standard deviation)는 데이터의 분산 정도를 나타내는 측정 지표 중 하나입니다. 데이터가 평균으로부터 얼마나 퍼져 있는지를 보여줍니다. 즉, 데이터 포인트가 평균에서 얼마나 멀리 떨어져 있는지를 평균적으로 측정하는 값입니다.
#
# - 표준편차가 작을수록 데이터 포인트들이 평균 주변에 모여있는 것이고, 표준편차가 클수록 데이터 포인트들이 평균에서 멀리 퍼져있다고 해석할 수 있습니다. 데이터의 흩어진 정도를 알려주는 지표로, 통계적 분석에서 널리 사용됩니다.

# %% [markdown]
# 공분산
# - 공분산(covariance)은 두 변수 간의 관계를 나타내는 통계적 측정 지표입니다. 두 변수의 변화 패턴이 함께 일어나는 정도를 측정하는데 사용됩니다.
#
# ![image.png](attachment:image.png)
#
# - 공분산이 양수인 경우, 변수X와Y는 함께 증가 또는 감소하는 경향이 있습니다. 반면에 공분산이 음수인 경우에는 하나의 변수가 증가할 때 다른 변수는 감소하는 경향이 있습니다. 하지만 공분산의 값 자체만으로는 두 변수 간의 관계의 강도나 방향을 명확하게 알려주지 않습니다. 따라서 표준화된 지표인 상관계수(correlation coefficient)를 사용하여 두 변수 간의 관계를 더 명확하게 파악합니다.

# %% [markdown]
# 정규화
# - 정규화(normalization)는 데이터의 스케일(scale)을 조정하여 특정 범위나 규격에 맞추는 과정을 말합니다.
#     1. **데이터 스케일 조정:** 데이터의 값이 서로 다른 범위에 있을 때, 일부 알고리즘에서는 이를 고려하여 데이터를 처리합니다. 정규화를 통해 데이터를 특정 범위로 조정함으로써, 알고리즘이 데이터를 더 잘 처리할 수 있도록 돕습니다.
#     2. **이상치 영향 완화:** 이상치가 있는 데이터는 전체적인 분포를 왜곡시킬 수 있습니다. 이를 완화하기 위해 데이터를 정규화하여 이상치의 영향을 줄일 수 있습니다.
#     3. **알고리즘의 수렴성 향상:** 몇몇 머신 러닝 알고리즘은 데이터가 정규화되어 있을 때 수렴하는 속도가 빨라질 수 있습니다. 특히 경사 하강법 등의 최적화 기법에서 이점을 볼 수 있습니다.

# %% [markdown]
# # 문제 : flights 데이터셋을 활용해서 그래프를 그려봅시다

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seaborn의 내장 데이터셋 'flights' 불러오기
flights_data = sns.load_dataset('flights')
flights_data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# 1. 연도별 총 승객 수

# %%
sum = flights_data.groupby('year').sum('passengers').reset_index()
plt.plot(sum['year'],sum['passengers'])
plt.xlabel('year')
plt.ylabel('passengers')
plt.show()

# %% [markdown]
# 2. 연도별 평균 승객 수

# %%
mean_p = flights_data.groupby('year').mean('passengers').reset_index()
plt.plot(mean_p['year'], mean_p['passengers'])
plt.xlabel('mean')
plt.ylabel('Passengers')
plt.plot()
# Out:
# []

# %% [markdown]
# 3. 승객 수 분포

# %%
plt.hist(flights_data['passengers'],edgecolor = 'black')
plt.title('Passengers Distribution')
plt.xlabel('Passengers')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 4. 연도별 승객 수와 월간 승객 수

# %%
plt.figure(figsize=(10, 6))
for month in flights_data['month'].unique():
    plt.scatter(flights_data[flights_data['month'] == month]['year'], 
                flights_data[flights_data['month'] == month]['passengers'], 
                label=month, alpha=0.7) # alpha 투명도.
plt.title('Passengers per Year by Month')
plt.xlabel('Year')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# %% [markdown]
# 5. 월별 승객 수 분포 - boxplot()

# %%
plt.figure(figsize=(8,6))
plt.boxplot([flights_data[flights_data['month'] == month ]['passengers'] for month in flights_data['month'].unique()], 
            label = flights_data['month'].unique())
plt.title('Passengers Distribution by Month')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.plot()
# Out:
# []

# %% [markdown]
# # tips 데이터셋을 활용해서 그래프를 그려봅시다

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seaborn의 내장 데이터셋 'tips' 불러오기
tips_data = sns.load_dataset('tips')

# %% [markdown]
# ### 1. 요일별 팁 금액의 평균
#
# 1. 제목 : Average Tips by Day
# 2. X축 : Day of the Week
# 3. Y축 : Average Tip Amount

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_by_day = tips_data.groupby('day')['tip'].mean()
tips_by_day
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.plot(tips_by_day.index, tips_by_day.values, marker= 'o', linestyle ='-')
plt.legend()
plt.grid(True)
plt.xlabel('Day of the Week')
plt.ylabel('Average tip Amount')
# Out:
# Text(0, 0.5, 'Average tip Amount')

# %% [markdown]
# ### 2. 요일별 총 팁 금액
# 1. 제목 : Total Tips by Day
# 2. X축 : Day of the Week
# 3. Y축 : Total Tip Amount

# %%
SumTips_Day = tips_data.groupby('day')['tip'].sum()

plt.plot(SumTips_Day.index, SumTips_Day.values)
plt.title('Total Tips by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Tip Amount')
plt.show()

# %% [markdown]
# ### 3. 식사 금액 분포
# 1. 제목 : Distribution of Total Bill
# 2. X축 : Total Bill Amount
# 3. Y축 : Frequency

# %%
tips_data['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips_data['total_bill']
plt.hist(tips_data['total_bill'],bins = 20, edgecolor = 'black')
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill Amount')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 4. 식사 금액과 팁 금액의 관계
# 1. 제목 : Tip Amount vs Total Bill
# 2. X축 : Total Bill Amount
# 3. Y축 : Tip Amount

# %% [markdown]
# ### 5. 요일별 식사 금액 분포
# 1. 제목 : Total Bill Distribution by Day
# 2. X축 : Day of the Week
# 3. Y축 : Total Bill Amount
