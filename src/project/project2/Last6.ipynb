# %%
import requests, pandas as pd

# %%
key = "7a6c64784d6a756e393572646b6d45"
base_url = f'http://openapi.seoul.go.kr:8088/{key}/json/VwsmTrdarSelngQq/'

def requestOpenAPI(base_url):
        all_data_list = []
        initial_response = requests.get(base_url + '1/1/')

        if initial_response.status_code == 200:
            initial_response.content.decode('utf-8')
            initial_data = initial_response.json()
            total_data_rows = initial_data['VwsmTrdarSelngQq']['list_total_count']
            page_size = 1000  # The maximum page size

            for start_index in range(1, total_data_rows + 1, page_size):
                end_index = start_index + page_size - 1

                # Create the URL for the current page
                page_url = f'{base_url}{start_index}/{end_index}/'

                # Make a request to the page_url to fetch the data for this page
                page_response = requests.get(page_url)

                if page_response.status_code == 200:
                    page_response.content.decode('utf-8')
                    page_data_json = page_response.json()

                    all_data_list.append(page_data_json)

                else:
                    print(f"Request to {page_url} failed with status code: {page_response.status_code}")

        else:
            print(f"Initial request failed with status code: {initial_response.status_code}")

        return all_data_list

# %%
#1m 20s
jsondata_list = requestOpenAPI(base_url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/code/Last6.ipynb 셀 3 line 2
#       <a href='vscode-notebook-cell:/Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/code/Last6.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> #1m 20s
# ----> <a href='vscode-notebook-cell:/Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/code/Last6.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> jsondata_list = requestOpenAPI(base_url)
#
# /Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/code/Last6.ipynb 셀 3 line 2
#      <a href='vscode-notebook-cell:/Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/code/Last6.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> if page_response.status_code == 200:
# ...

# %%
# Extract row_data from each JSON object and store it in a list
row_data_list = [data['VwsmTrdarSelngQq']['row'] for data in jsondata_list]

# %%
# Concatenate all the DataFrames into a single DataFrame
final_df = pd.concat([pd.DataFrame(row_data) for row_data in row_data_list], ignore_index=True)

# %%
final_df.columns
# Out:
# Index(['STDR_YYQU_CD', 'TRDAR_SE_CD', 'TRDAR_SE_CD_NM', 'TRDAR_CD',
#        'TRDAR_CD_NM', 'SVC_INDUTY_CD', 'SVC_INDUTY_CD_NM', 'THSMON_SELNG_AMT',
#        'THSMON_SELNG_CO', 'MDWK_SELNG_AMT', 'WKEND_SELNG_AMT', 'MON_SELNG_AMT',
#        'TUES_SELNG_AMT', 'WED_SELNG_AMT', 'THUR_SELNG_AMT', 'FRI_SELNG_AMT',
#        'SAT_SELNG_AMT', 'SUN_SELNG_AMT', 'TMZON_00_06_SELNG_AMT',
#        'TMZON_06_11_SELNG_AMT', 'TMZON_11_14_SELNG_AMT',
#        'TMZON_14_17_SELNG_AMT', 'TMZON_17_21_SELNG_AMT',
#        'TMZON_21_24_SELNG_AMT', 'ML_SELNG_AMT', 'FML_SELNG_AMT',
#        'AGRDE_10_SELNG_AMT', 'AGRDE_20_SELNG_AMT', 'AGRDE_30_SELNG_AMT',
#        'AGRDE_40_SELNG_AMT', 'AGRDE_50_SELNG_AMT', 'AGRDE_60_ABOVE_SELNG_AMT',
#        'MDWK_SELNG_CO', 'WKEND_SELNG_CO', 'MON_SELNG_CO', 'TUES_SELNG_CO',
#        'WED_SELNG_CO', 'THUR_SELNG_CO', 'FRI_SELNG_CO', 'SAT_SELNG_CO',
#        'SUN_SELNG_CO', 'TMZON_00_06_SELNG_CO', 'TMZON_06_11_SELNG_CO',
# ...

# %%
import os

# %%
os.chdir("/Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/data")

# %%
final_df.to_csv('salesEstimation_gzip.csv',compression='gzip',index=False)

# %%
import os, pandas as pd

# %%
os.chdir("/Volumes/Seagate/2023/2nd_semester/BigDataAPI/lastTest/data")

# %%
final_df = pd.read_csv('salesEstimation_gzip.csv',compression='gzip')

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0', 'STDR_YYQU_CD', 'TRDAR_SE_CD', 'TRDAR_SE_CD_NM',
#        'TRDAR_CD', 'TRDAR_CD_NM', 'SVC_INDUTY_CD', 'SVC_INDUTY_CD_NM',
#        'THSMON_SELNG_AMT', 'THSMON_SELNG_CO', 'MDWK_SELNG_AMT',
#        'WKEND_SELNG_AMT', 'MON_SELNG_AMT', 'TUES_SELNG_AMT', 'WED_SELNG_AMT',
#        'THUR_SELNG_AMT', 'FRI_SELNG_AMT', 'SAT_SELNG_AMT', 'SUN_SELNG_AMT',
#        'TMZON_00_06_SELNG_AMT', 'TMZON_06_11_SELNG_AMT',
#        'TMZON_11_14_SELNG_AMT', 'TMZON_14_17_SELNG_AMT',
#        'TMZON_17_21_SELNG_AMT', 'TMZON_21_24_SELNG_AMT', 'ML_SELNG_AMT',
#        'FML_SELNG_AMT', 'AGRDE_10_SELNG_AMT', 'AGRDE_20_SELNG_AMT',
#        'AGRDE_30_SELNG_AMT', 'AGRDE_40_SELNG_AMT', 'AGRDE_50_SELNG_AMT',
#        'AGRDE_60_ABOVE_SELNG_AMT', 'MDWK_SELNG_CO', 'WKEND_SELNG_CO',
#        'MON_SELNG_CO', 'TUES_SELNG_CO', 'WED_SELNG_CO', 'THUR_SELNG_CO',
#        'FRI_SELNG_CO', 'SAT_SELNG_CO', 'SUN_SELNG_CO', 'TMZON_00_06_SELNG_CO',
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125692 entries, 0 to 125691
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                125692 non-null  int64
#  1   STDR_YYQU_CD              125692 non-null  int64
#  2   TRDAR_SE_CD               125692 non-null  object
#  3   TRDAR_SE_CD_NM            125692 non-null  object
#  4   TRDAR_CD                  125692 non-null  int64
#  5   TRDAR_CD_NM               125692 non-null  object
#  6   SVC_INDUTY_CD             125692 non-null  object
#  7   SVC_INDUTY_CD_NM          125692 non-null  object
#  8   THSMON_SELNG_AMT          125692 non-null  float64
#  9   THSMON_SELNG_CO           125692 non-null  float64
#  10  MDWK_SELNG_AMT            125692 non-null  float64
#  11  WKEND_SELNG_AMT           125692 non-null  float64
#  12  MON_SELNG_AMT             125692 non-null  float64
# ...

# %%
final_df.head(1)
# Out:
#    Unnamed: 0  STDR_YYQU_CD TRDAR_SE_CD TRDAR_SE_CD_NM  TRDAR_CD TRDAR_CD_NM  \
# 0           0         20221           A           골목상권   3110001      이북5도청사
#
#   SVC_INDUTY_CD SVC_INDUTY_CD_NM  THSMON_SELNG_AMT  THSMON_SELNG_CO  ...  \
# 0      CS100001            한식음식점       340449266.0           9508.0  ...
#
#    TMZON_17_21_SELNG_CO  TMZON_21_24_SELNG_CO  ML_SELNG_CO  FML_SELNG_CO  \
# 0                2834.0                  69.0       5507.0        2744.0
#
#    AGRDE_10_SELNG_CO  AGRDE_20_SELNG_CO  AGRDE_30_SELNG_CO  AGRDE_40_SELNG_CO  \
# 0               26.0              410.0              680.0             1572.0
#
#    AGRDE_50_SELNG_CO  AGRDE_60_ABOVE_SELNG_CO
# 0             2244.0                   3319.0
#
# [1 rows x 56 columns]

# %%
def create_df_check(df):
    df_check = pd.DataFrame({
        'Column' : df.dtypes,
        'Unique Values' : df.nunique(),
        'Missing Values' : df.isnull().sum(),
        'Missing Values %' : df.isnull().sum()/len(df),
        'Example Data' : [df[col].unique() for col in df],
        })
    return df_check

# Usage
df_check = create_df_check(final_df)
df_check
# Out:
#                            Column  Unique Values  Missing Values  \
# Unnamed: 0                  int64         125692               0
# STDR_YYQU_CD                int64              6               0
# TRDAR_SE_CD                object              4               0
# TRDAR_SE_CD_NM             object              4               0
# TRDAR_CD                    int64           1567               0
# TRDAR_CD_NM                object           1567               0
# SVC_INDUTY_CD              object             63               0
# SVC_INDUTY_CD_NM           object             63               0
# THSMON_SELNG_AMT          float64         122367               0
# THSMON_SELNG_CO           float64          47173               0
# MDWK_SELNG_AMT            float64         124225               0
# WKEND_SELNG_AMT           float64         114696               0
# MON_SELNG_AMT             float64         117042               0
# ...

# %%
final_df['SVC_INDUTY_CD_NM'].unique()
# Out:
# array(['한식음식점', '분식전문점', '호프-간이주점', '일반교습학원', '커피-음료', '슈퍼마켓', '편의점',
#        '청과상', '의약품', '화장품', '예술학원', '미용실', '세탁소', '일반의류', '일식음식점',
#        '양식음식점', '제과점', '패스트푸드점', '미곡판매', '반찬가게', '화초', '육류판매', '문구', '서적',
#        '스포츠 강습', '가방', '시계및귀금속', '여관', '중식음식점', '인테리어', '치킨전문점', '전자상거래업',
#        '자동차수리', '철물점', '노래방', '핸드폰', '컴퓨터및주변장치판매', '운동/경기용품', '일반의원',
#        '당구장', '가전제품', '스포츠클럽', '가구', '치과의원', '조명용품', '외국어학원', '의료기기',
#        'PC방', '네일숍', '피부관리실', '안경', '한의원', '섬유제품', '자전거 및 기타운송장비', '신발',
#        '애완동물', '가전제품수리', '자동차미용', '골프연습장', '수산물판매', '부동산중개업', '완구', '고시원'],
#       dtype=object)

# %%
final_df['SVC_INDUTY_CD_NM'].value_counts()
# Out:
# SVC_INDUTY_CD_NM
# 한식음식점           8600
# 미용실             6419
# 커피-음료           5873
# 편의점             5141
# 슈퍼마켓            5066
#                 ...
# 가전제품수리           298
# 자전거 및 기타운송장비     158
# 부동산중개업           121
# 완구               118
# 고시원               67
# Name: count, Length: 63, dtype: int64

# %% [markdown]
# 공통	list_total_count	총 데이터 건수 (정상조회 시 출력됨)
#
# 공통	RESULT.CODE	요청결과 코드 (하단 메세지설명 참고)
#
# 공통	RESULT.MESSAGE	요청결과 메시지 (하단 메세지설명 참고)
#
# ---
#
# STDR_YYQU_CD	기준_년분기_코드
#
# TRDAR_SE_CD	상권_구분_코드
#
# TRDAR_SE_CD_NM	상권_구분_코드_명
#
# TRDAR_CD	상권_코드
#
# TRDAR_CD_NM	상권_코드_명
#
# SVC_INDUTY_CD	서비스_업종_코드
#
# SVC_INDUTY_CD_NM	서비스_업종_코드_명
#
# THSMON_SELNG_AMT	당월_매출_금액
#
# THSMON_SELNG_CO	당월_매출_건수
#
# MDWK_SELNG_AMT	주중_매출_금액
#
# WKEND_SELNG_AMT	주말_매출_금액
#
# MON_SELNG_AMT	월요일_매출_금액
#
# TUES_SELNG_AMT	화요일_매출_금액
#
# WED_SELNG_AMT	수요일_매출_금액
#
# THUR_SELNG_AMT	목요일_매출_금액
#
# FRI_SELNG_AMT	금요일_매출_금액
#
# SAT_SELNG_AMT	토요일_매출_금액
#
# SUN_SELNG_AMT	일요일_매출_금액
#
# TMZON_00_06_SELNG_AMT	시간대_00~06_매출_금액
#
# TMZON_06_11_SELNG_AMT	시간대_06~11_매출_금액
#
# TMZON_11_14_SELNG_AMT	시간대_11~14_매출_금액
#
# TMZON_14_17_SELNG_AMT	시간대_14~17_매출_금액
#
# TMZON_17_21_SELNG_AMT	시간대_17~21_매출_금액
#
# TMZON_21_24_SELNG_AMT	시간대_21~24_매출_금액
#
# ML_SELNG_AMT	남성_매출_금액
#
# FML_SELNG_AMT	여성_매출_금액
#
# AGRDE_10_SELNG_AMT	연령대_10_매출_금액
#
# AGRDE_20_SELNG_AMT	연령대_20_매출_금액
#
# AGRDE_30_SELNG_AMT	연령대_30_매출_금액
#
# AGRDE_40_SELNG_AMT	연령대_40_매출_금액
#
# AGRDE_50_SELNG_AMT	연령대_50_매출_금액
#
# AGRDE_60_ABOVE_SELNG_AMT	연령대_60_이상_매출_금액
#
# MDWK_SELNG_CO	주중_매출_건수
#
# WKEND_SELNG_CO	주말_매출_건수
#
# MON_SELNG_CO	월요일_매출_건수
#
# TUES_SELNG_CO	화요일_매출_건수
#
# WED_SELNG_CO	수요일_매출_건수
#
# THUR_SELNG_CO	목요일_매출_건수
#
# FRI_SELNG_CO	금요일_매출_건수
#
# SAT_SELNG_CO	토요일_매출_건수
#
# SUN_SELNG_CO	일요일_매출_건수
#
# TMZON_00_06_SELNG_CO	시간대_건수~06_매출_건수
#
# TMZON_06_11_SELNG_CO	시간대_건수~11_매출_건수
#
# TMZON_11_14_SELNG_CO	시간대_건수~14_매출_건수
#
# TMZON_14_17_SELNG_CO	시간대_건수~17_매출_건수
#
# TMZON_17_21_SELNG_CO	시간대_건수~21_매출_건수
#
# TMZON_21_24_SELNG_CO	시간대_건수~24_매출_건수
#
# ML_SELNG_CO	남성_매출_건수
#
# FML_SELNG_CO	여성_매출_건수
#
# AGRDE_10_SELNG_CO	연령대_10_매출_건수
#
# AGRDE_20_SELNG_CO	연령대_20_매출_건수
#
# AGRDE_30_SELNG_CO	연령대_30_매출_건수
#
# AGRDE_40_SELNG_CO	연령대_40_매출_건수
#
# AGRDE_50_SELNG_CO	연령대_50_매출_건수
#
# AGRDE_60_ABOVE_SELNG_CO	연령대_60_이상_매출_건수

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
basic_col = ['STDR_YYQU_CD','TRDAR_SE_CD_NM','TRDAR_CD_NM','SVC_INDUTY_CD_NM','THSMON_SELNG_AMT','THSMON_SELNG_CO']
age_col = ['AGRDE_10_SELNG_AMT','AGRDE_20_SELNG_AMT','AGRDE_30_SELNG_AMT','AGRDE_40_SELNG_AMT','AGRDE_50_SELNG_AMT','AGRDE_60_ABOVE_SELNG_AMT','AGRDE_10_SELNG_CO','AGRDE_20_SELNG_CO','AGRDE_30_SELNG_CO','AGRDE_40_SELNG_CO','AGRDE_50_SELNG_CO','AGRDE_60_ABOVE_SELNG_CO']
week_col = ['MON_SELNG_AMT','TUES_SELNG_AMT','WED_SELNG_AMT','THUR_SELNG_AMT','FRI_SELNG_AMT','SAT_SELNG_AMT','SUN_SELNG_AMT','MDWK_SELNG_AMT','WKEND_SELNG_AMT','MON_SELNG_CO','TUES_SELNG_CO','WED_SELNG_CO','THUR_SELNG_CO','FRI_SELNG_CO','SAT_SELNG_CO','SUN_SELNG_CO','MDWK_SELNG_CO','WKEND_SELNG_CO']
time_col = ['TMZON_00_06_SELNG_AMT','TMZON_06_11_SELNG_AMT','TMZON_11_14_SELNG_AMT','TMZON_14_17_SELNG_AMT','TMZON_17_21_SELNG_AMT','TMZON_21_24_SELNG_AMT','TMZON_00_06_SELNG_CO','TMZON_06_11_SELNG_CO','TMZON_11_14_SELNG_CO','TMZON_14_17_SELNG_CO','TMZON_17_21_SELNG_CO','TMZON_21_24_SELNG_CO']
sex_col = ['ML_SELNG_AMT','FML_SELNG_AMT','ML_SELNG_CO','FML_SELNG_CO']

basic_df= final_df[basic_col]
age_df = final_df[age_col]
week_df = final_df[week_col]
time_df = final_df[time_col]
sex_df = final_df[sex_col]

# %%
"'월요일_매출_건수','화요일_매출_건수','수요일_매출_건수','목요일_매출_건수','금요일_매출_건수','토요일_매출_건수','일요일_매출_건수','주중_매출_건수','주말_매출_건수'".replace('건수','금액')
# Out:
# "'월요일_매출_금액','화요일_매출_금액','수요일_매출_금액','목요일_매출_금액','금요일_매출_금액','토요일_매출_금액','일요일_매출_금액','주중_매출_금액','주말_매출_금액'"

# %%
basic_kor = ['기준_년분기_코드','상권_구분_코드_명','상권_코드_명','서비스_업종_코드_명','당월_매출_금액','당월_매출_건수']
age_kor = ['연령대_10_매출_금액','연령대_20_매출_금액','연령대_30_매출_금액','연령대_40_매출_금액','연령대_50_매출_금액','연령대_60_이상_매출_금액','연령대_10_매출_건수','연령대_20_매출_건수','연령대_30_매출_건수','연령대_40_매출_건수','연령대_50_매출_건수','연령대_60_이상_매출_건수']
week_kor = ['월요일_매출_금액','화요일_매출_금액','수요일_매출_금액','목요일_매출_금액','금요일_매출_금액','토요일_매출_금액','일요일_매출_금액','주중_매출_금액','주말_매출_금액','월요일_매출_건수','화요일_매출_건수','수요일_매출_건수','목요일_매출_건수','금요일_매출_건수','토요일_매출_건수','일요일_매출_건수','주중_매출_건수','주말_매출_건수']
time_kor = ['시간대_00~06_매출_금액','시간대_06~11_매출_금액','시간대_11~14_매출_금액','시간대_14~17_매출_금액','시간대_17~21_매출_금액','시간대_21~24_매출_금액','시간대_건수~06_매출_건수','시간대_건수~11_매출_건수','시간대_건수~14_매출_건수','시간대_건수~17_매출_건수','시간대_건수~21_매출_건수','시간대_건수~24_매출_건수']
sex_kor = ['남성_매출_금액','여성_매출_금액','남성_매출_건수','여성_매출_건수']

# %%
basic_df.columns = basic_kor
age_df.columns = age_kor
week_df.columns = week_kor
time_df.columns = time_kor
sex_df.columns = sex_kor

# %%
basic_df['당월_매출_금액'] = basic_df['당월_매출_금액'].astype(int).copy()
basic_df['당월_매출_건수'] = basic_df['당월_매출_건수'].astype(int).copy()
basic_df.to_csv("SELING_BASIC_DF_gzip.csv",compression='gzip',index=False)
basic_df
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_3076/67386995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basic_df['당월_매출_금액'] = basic_df['당월_매출_금액'].astype(int).copy()
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_3076/67386995.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basic_df['당월_매출_건수'] = basic_df['당월_매출_건수'].astype(int).copy()
#         기준_년분기_코드 상권_구분_코드_명      상권_코드_명 서비스_업종_코드_명    당월_매출_금액  당월_매출_건수
# ...

# %%
temp_df = basic_df[basic_df['상권_구분_코드_명']=='관광특구']
temp_df['서비스_업종_코드_명'].unique()
# Out:
# array(['한식음식점', '중식음식점', '일식음식점', '양식음식점', '제과점', '패스트푸드점', '치킨전문점',
#        '분식전문점', '호프-간이주점', '커피-음료', '일반의원', '치과의원', '당구장', '스포츠클럽', '미용실',
#        '네일숍', '피부관리실', '세탁소', '노래방', '슈퍼마켓', '편의점', '반찬가게', '일반의류', '신발',
#        '가방', '안경', '시계및귀금속', '의약품', '화장품', '운동/경기용품', '섬유제품', '화초', '가구',
#        '전자상거래업', '일반교습학원', '외국어학원', '예술학원', '스포츠 강습', '한의원', '골프연습장',
#        '가전제품수리', '여관', '고시원', '핸드폰', '미곡판매', '육류판매', '수산물판매', '청과상',
#        '의료기기', '서적', '문구', '애완동물', '가전제품', '인테리어', '조명용품', '자동차수리',
#        '컴퓨터및주변장치판매', 'PC방', '철물점', '완구'], dtype=object)

# %%
age_df[age_kor] = age_df[age_kor].astype(int)
age_df.to_csv("SELING_AGE_DF_gzip.csv",compression='gzip',index=False)
age_df
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_3076/3081680723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_df[age_kor] = age_df[age_kor].astype(int)
#         연령대_10_매출_금액  연령대_20_매출_금액  연령대_30_매출_금액  연령대_40_매출_금액  연령대_50_매출_금액  \
# 0             254833       9288282      26872034      47307050      79111272
# 1             520401       1747568       4715767       9576037      11384458
# 2                  0         53959       1721049       6903597       4847592
# 3                  0             0             0      39944152             0
# 4             369333      14607402      28576435      49579690      85256901
# ...              ...           ...           ...           ...           ...
# ...

# %%
sex_df[sex_kor] = sex_df[sex_kor].astype(int)
sex_df.to_csv("SELING_SEX_DF_gzip.csv",compression='gzip',index=False)
sex_df
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_3076/1410760949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sex_df[sex_kor] = sex_df[sex_kor].astype(int)
#           남성_매출_금액    여성_매출_금액  남성_매출_건수  여성_매출_건수
# 0        187198865    92216118      5507      2744
# 1         18668337    17498562      1815      1254
# 2         14397536      815747       159        29
# 3         27154318    12789834        80        40
# 4        184889858    99246095      7901      5292
# ...            ...         ...       ...       ...
# 125687  1594137435  1147536527       848       572
# 125688   310125438   416772924     14077     18196
# 125689    18588033    16171437      1800      1679
# ...

# %%
time_df[time_kor] = time_df[time_kor].astype(int)
time_df.to_csv("SELING_TIME_DF_gzip.csv",compression='gzip',index=False)
time_df
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_3076/2785715475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_df[time_kor] = time_df[time_kor].astype(int)
#         시간대_00~06_매출_금액  시간대_06~11_매출_금액  시간대_11~14_매출_금액  시간대_14~17_매출_금액  \
# 0               2664912          5855579        120447274         77953114
# 1                130201          5985801         17883160          8121052
# 2                     0                0                0          2166788
# 3                     0                0          4609308         28729762
# 4                     0          8373823        134099614         56161307
# ...                 ...              ...              ...              ...
# ...

# %%
week_df[week_kor] = week_df[week_kor].astype(int)
week_df.to_csv("SELING_WEEK_DF_gzip.csv",compression='gzip',index=False)
week_df
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_3076/3396575816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_df[week_kor] = week_df[week_kor].astype(int)
#         월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  목요일_매출_금액   금요일_매출_금액   토요일_매출_금액  \
# 0        21603986   33072927   44827113   42390843    49520348    74528182
# 1         7047170    6571173    6801198    4750191     5040575     5390624
# 2         3922990    4692187     193487          0     3114926     2902533
# 3        27568280    2181261    6780220          0     3414391           0
# 4        51167638   45275809   48057671   44487791    48295568    57330375
# ...           ...        ...        ...        ...         ...         ...
# ...

# %% [markdown]
# # 계약일자 문자열 타입 -> 날짜 형식으로 변환
