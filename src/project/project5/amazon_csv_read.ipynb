# %%
import pandas as pd
import os

# %%
os.chdir("/Users/jun/GitStudy/Data_4/data/project5")
os.listdir()
# Out:
# ['.DS_Store',
#  'reviews_202501102351.csv',
#  'reviews_202501101650.csv',
#  'items_202501101648.csv',
#  'items_202501102351.csv']

# %%
items_df1 = pd.read_csv("items_202501101648.csv",delimiter=",",index_col=False)
items_df2 = pd.read_csv("items_202501102351.csv",delimiter=",",index_col=False)
merged_items = items_df1.append(items_df2)
merged_items = merged_items.drop_duplicates().reset_index()
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_31216/1444988828.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_items = items_df1.append(items_df2)

# %%
merged_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      174 non-null    int64
#  1   ASIN                       174 non-null    object
#  2   title                      174 non-null    object
#  3   brand                      174 non-null    object
#  4   price                      174 non-null    float64
#  5   Special_Feature            174 non-null    object
#  6   total_star_mean            174 non-null    float64
#  7   detail_dict                174 non-null    object
#  8   best_sellers_rank_Feature  174 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 12.4+ KB

# %%
merged_items = merged_items.drop(columns="index")

# %%
merged_items
# Out:
#            ASIN                                              title  \
# 0    B00PBX3L7K  COSRX Snail Mucin 96% Power Repairing Essence ...
# 1    B00PGOBWPW  [DearKlairs] Gentle Black Deep Cleansing Oil 5...
# 2    B014G1G10Q  grace & stella Under Eye Mask (Gold, 48 Pairs)...
# 3    B01I2ZQJSG  Elizavecca cer-100 collagen coating hair prote...
# 4    B01LEJ5MSK  COSRX Snail Mucin 92% Face Moisturizer, 3.52 O...
# ..          ...                                                ...
# 169  B0D9PH4GCK  Bella Grace Eye Cream with Hyaluronic Acid & S...
# 170  B0DBKQV6H5  WELLAGE Hyper Peptide Skin Booster Face Toner ...
# 171  B0DBT75PVX  Green Rice Biome Serum with Probiotic, Reduce ...
# 172  B0DCHW6SHP  [K-Beauty] Bewants Deep Toning Glutathione Spo...
# 173  B0DF7DC877  Power and Volume Eyelash Serum – K-Beauty Kore...
#
#               brand  price     Special_Feature  total_star_mean  \
# 0          No brand  20.00  No special feature              4.6
# ...

# %%
reviews_df1 = pd.read_csv("reviews_202501102351.csv",delimiter=",",index_col=False)
reviews_df2 = pd.read_csv("reviews_202501101650.csv",delimiter=",",index_col=False)
merged_reviews = reviews_df1.append(reviews_df2)
merged_reviews = merged_reviews.drop_duplicates().reset_index()
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_31216/993296738.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_reviews = reviews_df1.append(reviews_df2)

# %%
merged_reviews
# Out:
#       index      review_num        ASIN  \
# 0         0   B00L2PB3BW__0  B00L2PB3BW
# 1         1   B00L2PB3BW__1  B00L2PB3BW
# 2         2  B00L2PB3BW__10  B00L2PB3BW
# 3         3  B00L2PB3BW__11  B00L2PB3BW
# 4         4  B00L2PB3BW__12  B00L2PB3BW
# ...     ...             ...         ...
# 6235   6235   B0DK4WBZXW__5  B0DK4WBZXW
# 6236   6236   B0DK4WBZXW__6  B0DK4WBZXW
# 6237   6237   B0DK4WBZXW__7  B0DK4WBZXW
# 6238   6238   B0DK4WBZXW__8  B0DK4WBZXW
# 6239   6239   B0DK4WBZXW__9  B0DK4WBZXW
#
#                                                   title  \
# 0     Beauty by Earth Self Tanner - USA Made with Na...
# 1     Beauty by Earth Self Tanner - USA Made with Na...
# 2     Beauty by Earth Self Tanner - USA Made with Na...
# 3     Beauty by Earth Self Tanner - USA Made with Na...
# 4     Beauty by Earth Self Tanner - USA Made with Na...
# ...                                                 ...
# 6235  Peripera Ink Mood Glowy Tint (018 NUDE AREA (H...
# ...

# %%
merged_reviews

# %%
merged_reviews = merged_reviews.drop(columns="index")
merged_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6240 entries, 0 to 6239
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_num     6240 non-null   object
#  1   ASIN           6240 non-null   object
#  2   title          6240 non-null   object
#  3   date           6240 non-null   object
#  4   review_rating  6240 non-null   object
#  5   content        6229 non-null   object
# dtypes: object(6)
# memory usage: 292.6+ KB

# %%
merged_reviews
# Out:
#           review_num        ASIN  \
# 0      B00L2PB3BW__0  B00L2PB3BW
# 1      B00L2PB3BW__1  B00L2PB3BW
# 2     B00L2PB3BW__10  B00L2PB3BW
# 3     B00L2PB3BW__11  B00L2PB3BW
# 4     B00L2PB3BW__12  B00L2PB3BW
# ...              ...         ...
# 6235   B0DK4WBZXW__5  B0DK4WBZXW
# 6236   B0DK4WBZXW__6  B0DK4WBZXW
# 6237   B0DK4WBZXW__7  B0DK4WBZXW
# 6238   B0DK4WBZXW__8  B0DK4WBZXW
# 6239   B0DK4WBZXW__9  B0DK4WBZXW
#
#                                                   title  \
# 0     Beauty by Earth Self Tanner - USA Made with Na...
# 1     Beauty by Earth Self Tanner - USA Made with Na...
# 2     Beauty by Earth Self Tanner - USA Made with Na...
# 3     Beauty by Earth Self Tanner - USA Made with Na...
# 4     Beauty by Earth Self Tanner - USA Made with Na...
# ...                                                 ...
# 6235  Peripera Ink Mood Glowy Tint (018 NUDE AREA (H...
# 6236  Peripera Ink Mood Glowy Tint (018 NUDE AREA (H...
# ...

# %%
merged_reviews.to_csv("reviews.csv")
merged_items.to_csv("items_csv")

# %%
os.listdir()
# Out:
# ['reviews.csv',
#  '.DS_Store',
#  'items_csv',
#  'reviews_202501102351.csv',
#  'reviews_202501101650.csv',
#  'items_202501101648.csv',
#  'items_202501102351.csv']

# %%
merged_reviews.groupby('ASIN').count()
# Out:
#             review_num  title  date  review_rating  content
# ASIN
# B00L2PB3BW          30     30    30             30       30
# B00PBX3L7K          50     50    50             50       50
# B00PGOBWPW          50     50    50             50       50
# B014G1G10Q          20     20    20             20       20
# B01C2EFBZU          10     10    10             10       10
# ...                ...    ...   ...            ...      ...
# B0DDNQJW2D          20     20    20             20       20
# B0DF7DC877          18     18    18             18       18
# B0DG4WXBCF          30     30    30             30       30
# B0DGTC6QCN          38     38    38             38       38
# B0DK4WBZXW          50     50    50             50       49
#
# [178 rows x 5 columns]

# %%
# 카테고리 보기
items_df['best_sellers_rank_Feature'].apply(lambda x : x.split(" in ")[-1]).unique()
# Out:
# array(['Facial Serums', 'Facial Cleansing Washes',
#        'Eye Wrinkle Pads & Patches', 'Hair Treatment Masks',
#        'Face Moisturizers', 'Eye Treatment Balms', 'Facial Masks',
#        'Facial Toners & Astringents', 'Facial Oils',
#        'Facial Night Creams', 'Makeup Cleansing Oils',
#        'Facial Cleansing Cloths & Towelettes', 'Facial Sunscreens',
#        'Makeup Blenders & Sponges', 'Skin Care Sets & Kits',
#        "Women's Disposable Shaving Razors", 'Makeup Cleansing Creams',
#        'Foundation Makeup', 'Eye Masks', 'Hair Treatment Oils',
#        'Eye Treatment Creams', 'Eye Treatment Serums', 'Face Mists',
#        'Face Blushes', 'Foundation Primers', 'Makeup Palettes',
#        'Lip Stains', 'Hair Shampoo', 'Lip Balms & Moisturizers',
#        'Pore Cleansing Strips', 'Foundation Brushes', 'Lip Butters',
#        'Facial Skin Care Products'], dtype=object)

# %%
review_df = pd.read_csv("reviews_202501101650.csv", delimiter=",")

# %%
review_df.head()
# Out:
#        review_num        ASIN  \
# 0   B00PBX3L7K__0  B00PBX3L7K
# 1   B00PBX3L7K__1  B00PBX3L7K
# 2  B00PBX3L7K__10  B00PBX3L7K
# 3  B00PBX3L7K__11  B00PBX3L7K
# 4  B00PBX3L7K__12  B00PBX3L7K
#
#                                                title  \
# 0  COSRX Snail Mucin 96% Power Repairing Essence ...
# 1  COSRX Snail Mucin 96% Power Repairing Essence ...
# 2  COSRX Snail Mucin 96% Power Repairing Essence ...
# 3  COSRX Snail Mucin 96% Power Repairing Essence ...
# 4  COSRX Snail Mucin 96% Power Repairing Essence ...
#
#                                                 date       review_rating  \
# 0   Reviewed in the United States on January 5, 2025  5.0 out of 5 stars
# 1  Reviewed in the United States on December 24, ...  5.0 out of 5 stars
# 2   Reviewed in the United States on January 8, 2025  2.0 out of 5 stars
# 3   Reviewed in the United States on January 7, 2025  5.0 out of 5 stars
# 4   Reviewed in the United States on January 7, 2025  1.0 out of 5 stars
#
# ...

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4543 entries, 0 to 4542
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_num     4543 non-null   object
#  1   ASIN           4543 non-null   object
#  2   title          4543 non-null   object
#  3   date           4543 non-null   object
#  4   review_rating  4543 non-null   object
#  5   content        4533 non-null   object
# dtypes: object(6)
# memory usage: 213.1+ KB
